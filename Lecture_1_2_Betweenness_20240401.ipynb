# %% [markdown]
# # Меры центральности, граф социальной сети
#
# #### Математика для лингвистов
# #### Клышинский Э.С., 01.04.2024
#
# ### Теоретическое введение
#
# ##### Степень связности
#
# Простейшим понятием является степень связности, которая определяется как число связей, инцидентных узлу (то есть число связей, которое узел имеет). Степень можно интерпретировать в терминах прямого риска узла подхватить что-то проходящее через сеть (таких как вирус или некая информация). В случае ориентированной сети (где связи имеют направление) обычно определяются две различные меры степени связности, а именно, полустепень захода и полустепень исхода. Соответственно, полустепень захода — это число связей с узлом, а полустепень исхода — это число связей узла с остальными узлами. Когда связь ассоциируется с некоторым положительным аспектом, таким как дружба или сотрудничество, полустепень захода часто интерпретируется как вид популярности, а полустепень исхода как общительность.
#
# ##### Степень близости
#
# В связном графе нормализованная степень близости узла равна средней длине кратчайшего пути между узлом и всеми другими узлами в графе. Тогда чем центральнее узел, тем ближе он ко все остальным узлам.
#
# Степень близости определил Алекс Бавелас (1950) как обратную величину отдалённости, то есть
# $C(x)={\frac {1}{\sum _{y}d(y,x)}}$
#
# где d(y, x) равно расстоянию между вершинами x и y. Однако, когда говорят о степени близости к другим узлам, люди обычно имеют в виду её нормализованную форму, обычно получающющуюся из предыдущей формулы путём умножения на N − 1, где N равно числу узлов в графе. Калибровка позволяет сравнение между узлами графов различного размера.
#
# ##### Степень посредничества
#
# Степень посредничества — это мера центральности вершины в графе (существует также степень посредничества ребра, которая здесь не обсуждается). Степень посредничества выражает количественно число раз, когда узел служит мостом в кратчайшем пути между двумя другими узлами. Степень посредничества была введена Линтоном Фриманом как мера количественного выражения взаимодействия человека с другими людьми в социальной сети. В этой концепции вершины, имеющие наибольшую вероятность оказаться на случайно выбранном кратчайшем пути между двумя случайно выбранными вершинами, имеют высокую степень посредничества.
#
# Степень посредничества вершины v в графе G=(V, E)  с V вершинами вычисляется следующим образом:
#
# - Для каждой пары вершин (s,t) вычисляются кратчайшие пути между ними.
# - Для каждой пары вершин (s,t) определяется доля кратчайших путей, которые проходят через рассматриваемую вершину (здесь, вершину v).
# - Суммируем эти доли по всем парам вершин (s,t).
#
# Более компактно степень посредничества можно представить как:
#
# $C_{B}(v)=\sum _{s\neq v\neq t\in V}{\frac {\sigma _{st}(v)}{\sigma _{st}}}$
#
# где $\sigma _{st}$ равно общему числу кратчайших путей из узла s в узел t, а $\sigma _{st}(v)$ равно числу таких путей, которые проходят через v. Степень посредничества можно нормализовать путём деления на число пар вершин, не включающих v, что для ориентированных графов равно (n-1)(n-2), а для неориентированных графов равно(n-1)(n-2)/2. Например, в неориентированной звезде центральная вершина (которая содержится в любом возможном кратчайшем пути) имеет степень посредничества (n-1)(n-2)/2 (1, если нормализовать), в то время как листья (которые не содержатся ни в одном кратчайшем пути) имеют степень посредничества 0.
#
# С точки зрения вычислений, как степени посредничества, так и степени близости всех вершин графа вовлекают вычисление кратчайших путей между всеми парами вершин графа, что требует время $O(V^{3})$ при использовании алгоритма Флойда — Уоршелла. Однако на разреженных графах алгоритм Джонсона может оказаться более эффективным, работая за время $O(V^{2}\log V+VE)$. В случае невзвешенных графов вычисления могут быть выполнены с помощью алгоритма Брандеса, который затрачивает время O(VE). Обычно эти алгоритмы предполагают, что графы не ориентированы и связны с разрешением петель и кратных рёбер. При работе с сетевыми графами, отражающими простые связи, которые часто не имеют петель или кратных рёбер (где рёбра представляют связи между людьми). В этом случае использование алгоритма Брандеса конечный показатель центральности делится на 2, чтобы учесть, что каждый кратчайший путь подсчитывается дважды.
#
# ##### Степень влиятельности
#
# Степень влиятельности является мерой влияния узла в сети. Он назначает относительные показатели всем узлам в сети, основываясь на концепции, что связи с узлами с высоким показателем вкладывают больше в показатель рассматриваемого узла, чем такая же связь с узлом с низким показателем. Показатель PageRank компании Google и центральность узла по Кацу являются вариантами степени влиятельности.
# Использование матрицы смежности для нахождения степени влиятельности
#
# Для заданного графа G=(V,E) с |V| вершинами пусть $A=(a_{v,t})$ будет матрицей смежности, то есть a $a_{v,t}=1$, если вершина v связана с вершиной t, и a $a_{v,t}=0$ в противном случае. Относительный показатель центральности вершины v можно определить как
#
# $x_{v}={\frac {1}{\lambda }}\sum _{t\in M(v)}x_{t}={\frac {1}{\lambda }}\sum _{t\in G}a_{v,t}x_{t}$
#
# где M(v) представляет собой множество соседей вершины v, а λ является константой.

# %% [markdown]
# ### Библиотека Natasha и извлечение именованных сущностей
# При обработке текстов часто решают такие стандартные и связанные между собой задачи как извлечение именованных сущностей и извлечение фактов. При этом факты часто извлекаются именно для именованных сущностей - кто про кого что сказал, что купил, с чем выступил и т.д.
#
# Сегодня мы попробуем решать первую задачу - извлечение именованных сущностей. Для этого используем библиотеку с романтичным названием Natasha ([статья на Хабре](https://habr.com/ru/post/516098/) и более понятная [документация](https://nbviewer.jupyter.org/github/natasha/natasha/blob/master/docs.ipynb)). На самом деле она обладает относительно (других библиотек) не очень высокой точностью работы и выделяет всего два типа именованных сущностей - фамильно-именные группы и адреса. Зато она точно легко ставится и работает с русским языком.
#
# Гораздо лучше библиотекой является Stanford NER, но у него нет русского языка, а сама библиотека ставится под Java. В состав NLTK входит модуль, который предоставляет интерфейс работы со Stanford NER. В общем, если Вы работаете с английским языком, понимите у себя всё что надо для него.
#
# Для сегодняшней задачи нам потребуются только имена, поэтому импортируем из Наташи только класс NamesExtractor.
#
# Помимо этого будем использовать для контроля за процессом вычислений такую приятную вещь как tqdm. Он позволяет выводить на экран номер текщей итерации в цикле, оценивает скорость выполнения цикла, показывает прогресс и вообще позволяет увидеть, что программа всё еще не зависла.

# %%
import re
# Берем tqdm чтобы следить за прогрессом.
from tqdm import tqdm

# %% [markdown]
# Загрузим новости с Ленты.ру за лето 2018 года в список кортежей (название, дата, новость).

# %%
# Если не хочется долгих экспериментов, в папке лежит сокращенная версия файла с новостями:
# summer22.txt
with open("data/lenta2018_summer.txt", encoding="utf-8") as newsfile: # Файл с новостями.
    text_news = [(n.split("-----\n")[0].split('\n')[0], 
                  n.split("-----\n")[0].split('\n')[1], 
                  n.split("-----\n")[1]) for n in newsfile.read().split("=====\n")[1:]]

# %% [markdown]
# Давайте разберемся с тем, как работает библиотека. Для начала создаем объект типа NamesExtractor.

# %%
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    NamesExtractor,

    Doc
)

# %% [markdown]
# Для того, чтобы извлечь все имена из какого-то текста его надо "передать" в объект типа NamesExtractor при помощи оператора круглые скобки. Для теста возьмем нулевую новость из загруженных из извлечем имена из нее.
#
# Библиотека Natasha возвращает список объектов, которые могут возвращать описание полученной именованной сущности, например, в виде JSON.

# %%
segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
#syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

# %%
print(text_news[0][2])

doc = Doc(text_news[0][2])

doc.segment(segmenter)
doc.tag_morph(morph_tagger)
doc.tag_ner(ner_tagger)
display(doc.spans)
#doc.ner.print()

#token.lemmatize(morph_vocab)
# Out:
# Шведская YouTube-знаменитость Симона Герц (Simone Giertz), прославившаяся необычными изобретениями, перенесла операцию. Об этом рассказали ее представители в Twitter. Еще в конце апреля девушка сообщила подписчикам о недуге. Оказалось, что у нее в мозге обнаружили доброкачественную опухоль размером с мяч для гольфа. Блогер даже дала ей имя, назвав новообразование Брайаном.  Герц сильно переживала перед хирургическим вмешательством. В одном из предоперационных видео она говорила, что очень напугана. Однако врачи быстро удалили опухоль и спасли девушке жизнь. «Симона вышла из хирургии, и ее врачи очень довольны тем, как все прошло. Она проспала достаточно долго, чтобы сделать неуместную шутку, так что все хорошо», — говорится на ее странице в Twitter.  27-летняя изобретательница из Стокгольма прославилась несколько лет назад, показывая подписчикам свои бесполезные изобретения. Например, Герц демонстрировала самодельный будильник, к которому приделана резиновая рука, избивающая спящего человека. Кроме того, девушка создавала автоматизированную машину для наливания молока в тарелку с хлопьями. Сама Герц называет себя «королевой дерьмовых роботов», на ее канал подписаны более миллиона пользователей.
# [DocSpan(start=9, stop=29, type='ORG', text='YouTube-знаменитость', tokens=[...]),
#  DocSpan(start=30, stop=57, type='PER', text='Симона Герц (Simone Giertz)', tokens=[...]),
#  DocSpan(start=158, stop=165, type='ORG', text='Twitter', tokens=[...]),
#  DocSpan(start=366, stop=374, type='PER', text='Брайаном', tokens=[...]),
#  DocSpan(start=377, stop=381, type='PER', text='Герц', tokens=[...]),
#  DocSpan(start=565, stop=571, type='PER', text='Симона', tokens=[...]),
#  DocSpan(start=751, stop=758, type='ORG', text='Twitter', tokens=[...]),
#  DocSpan(start=791, stop=801, type='LOC', text='Стокгольма', tokens=[...]),
#  DocSpan(start=898, stop=902, type='PER', text='Герц', tokens=[...]),
#  DocSpan(start=1112, stop=1116, type='PER', text='Герц', tokens=[...])]

# %%
doc.spans[0].tokens[0].lemmatize(morph_vocab)
doc.spans[0].tokens[0].lemma
# Out:
# 'youtube-знаменитость'

# %%
doc.spans[0].as_json['text'], doc.spans[0].as_json['type']
# Out:
# ('YouTube-знаменитость', 'ORG')

# %%
def NER_it(text):
    doc = Doc(text)

    doc.segment(segmenter)
    doc.tag_morph(morph_tagger)
    doc.tag_ner(ner_tagger)
    for s in doc.spans:
        s.tokens[-1].lemmatize(morph_vocab)
    return [(s.tokens[-1].lemma, s.type) for s in doc.spans]

def get_politics(lenta):
    # Храним все упоминавшиеся имена...
    names = {}
    # ... и связи между людьми, упоминавшимися в одной новости.
    connect = {}
    # Перебираем все загруженные новости.
    for art in tqdm(lenta):
        # Извлекаем именные группы из текста новости.
        nfacts = NER_it(art[2])
        # Так как один участник может упоминаться несколько раз, строим список с единственными упоминаниями.
        nam = [fact[0].split(" ")[-1] for fact in nfacts if fact[1] == 'PER']
        snam = list(set(nam))
        # Пробрасываем связи между людьми. Главное - не писать сколько раз человек связан между собой.
        for n in snam:
            names[n] = names.get(n, 0) + 1
            pers = connect.get(n, {})
            for n2 in snam:
                if n != n2:
                    pers[n2] = pers.get(n2, 0)+1
            connect[n] = pers
    return names, connect

# %%
names, connections = get_politics(text_news)
# Out:
#   0%|          | 5/10831 [00:00<08:14, 21.87it/s]
# 100%|██████████| 10831/10831 [09:27<00:00, 19.09it/s]

# %%
connections
# Out:
# {'брайан': {'симона': 1,
#   'герц': 1,
#   ')': 2,
#   'ландстедт': 1,
#   'медведев': 2,
#   'тутберидзе': 2,
#   'загитов': 2,
#   'орсер': 2,
#   'хань': 1,
#   'уилсон': 1,
#   'женя': 1,
#   'девятов': 1},
#  'симона': {'брайан': 1, 'герц': 1, ')': 1},
#  'герц': {'брайан': 1, 'симона': 1, ')': 1},
#  ')': {'брайан': 2,
#   'симона': 1,
#   'герц': 1,
#   'пикассо': 2,
#   'паула': 1,
#   'джованни': 1,
#   'джонсон': 4,
#   'гуля': 3,
#   'салифов': 2,
#   'ахмедов': 1,
#   'ленкоранский': 1,
#   'хаджи': 2,
#   'бейлаганский': 5,
#   'ровшан': 1,
#   'талыбханл': 5,
#   'маккон': 1,
#   'дженнифер': 1,
#   'зарсилья': 1,
#   'хендерсон': 3,
#   'диксон': 1,
#   'мэтуен-кэмпбелл': 1,
#   'шамбургер': 1,
#   '(': 21,
#   'чурадзе': 1,
#   'шошие': 1,
#   'алфасон': 2,
#   'гия': 1,
#   'кардашьян': 7,
#   'ын': 1,
#   'дэниэлс': 1,
#   'ким': 3,
#   'трамп': 37,
#   'шонесси': 1,
#   'адамс': 1,
#   'алвес': 1,
#   'биркетта': 1,
#   'лена': 1,
#   'хантера': 2,
#   'бенедикт': 1,
#   'дойля': 1,
#   'холмс': 1,
#   'камбербэтч': 1,
#   'диас': 1,
#   'дойла': 1,
#   'бибер': 1,
#   'энди': 1,
#   'харраз': 1,
#   'свирид': 1,
#   'мартин': 4,
#   'льюис': 3,
#   'мелани': 2,
#   'петерсон': 2,
#   'джейн': 1,
#   'кишор': 1,
#   'холл': 2,
#   'дэвис': 4,
#   'рейган': 1,
#   'костанзь': 1,
#   'бердо': 2,
#   'холройд-доветон': 1,
#   'бритт': 1,
#   'кристиан': 1,
#   'кэтрин': 1,
#   'ii': 6,
#   'хиль': 1,
#   'чейз': 1,
#   'грин': 1,
#   'граймс': 1,
#   'линкольн': 1,
#   'фоуль': 1,
#   'коэн': 8,
#   'ян': 1,
#   'ри': 1,
#   'риггз': 1,
#   'скрипаля': 3,
#   'скрипаль': 4,
#   'макферсон': 1,
#   'юлия': 4,
#   'херд': 1,
#   'линч': 2,
#   'дефо': 1,
#   'бэйл': 1,
#   'супермен': 1,
#   'нолан': 1,
#   'данст': 2,
#   'леджер': 2,
#   'рейнольдс': 3,
#   'лютором': 1,
#   'бэтмен': 2,
#   'бертон': 2,
#   'джокер': 3,
#   'франко': 1,
#   'магуайр': 1,
#   'доннер': 1,
#   'рив': 1,
#   'джамил': 1,
#   'ольхольм': 1,
#   'olholm': 1,
#   'хафра': 1,
#   'обама': 6,
#   'беквитта': 1,
#   'мэлоун': 1,
#   'деллагрази': 1,
#   'алехандро': 1,
#   'харрисон': 2,
#   'щебенка': 1,
#   'скутер': 1,
#   'фостер': 1,
#   'натмег': 1,
#   'хассный': 1,
#   'чен': 1,
#   'консолата': 1,
#   'мария': 3,
#   'уильямс': 2,
#   'мишель': 3,
#   'тико': 1,
#   'соло': 1,
#   'роуз': 3,
#   'келли': 3,
#   'трэн': 2,
#   'оствейн': 1,
#   'рютта': 1,
#   'рюгге': 1,
#   'олсоппа': 1,
#   'бэккер': 1,
#   'каффера': 1,
#   'каффер': 1,
#   'кларк': 2,
#   'коман': 1,
#   'карлсон': 1,
#   'ник': 1,
#   'януш': 1,
#   'джош': 1,
#   'гумбо': 1,
#   'кэти': 3,
#   'филе': 1,
#   'эрдоган': 4,
#   'куртджеб': 1,
#   'сергей': 2,
#   'путин': 10,
#   'битто': 1,
#   'хенвеять': 1,
#   'кеш': 1,
#   'ell': 1,
#   'фоулкс-дэвис': 1,
#   'лайм': 1,
#   'белла': 2,
#   'доннель': 1,
#   'джаред': 1,
#   'уэллс': 1,
#   'майкл': 2,
#   'кватриня': 1,
#   'барлетта': 1,
#   'ходжес': 1,
#   'хэнсен': 1,
#   'хот-дог': 1,
#   'пипп': 1,
#   'пиппа': 1,
#   'кэсся': 1,
#   'вонг': 1,
#   'пеннер': 1,
#   'петрашкен': 1,
#   'ши': 3,
#   'морган': 2,
#   'томас': 6,
#   'леско': 1,
#   'стоунь': 1,
#   'мандал': 1,
#   'чичерин': 1,
#   'чиол': 1,
#   'роды': 1,
#   'джонс': 3,
#   'том': 2,
#   'джина': 1,
#   'джей': 2,
#   'джозеф': 2,
#   'шунк': 1,
#   'джин': 1,
#   'демлоу': 1,
#   'дехллоу': 1,
#   'хаджипантель': 2,
#   'джакоминь': 1,
#   'рул': 1,
#   'рид': 2,
#   'шаль': 1,
#   'коппола': 1,
#   'туа': 1,
#   'христос': 1,
#   'айри': 1,
#   'черилл': 1,
#   'пол': 3,
#   'макгиннесса': 1,
#   'фойгт': 1,
#   'корить': 1,
#   'тайсон': 1,
#   'хан': 2,
#   'марклый': 13,
#   'гарри': 11,
#   'миддлтон': 4,
#   'уильям': 3,
#   'ловато': 1,
#   'инсейлес': 1,
#   'джордж': 3,
#   'патель': 1,
#   'кантер': 1,
#   'бурден': 1,
#   'лоутон': 1,
#   'рейнсфорд': 1,
#   'вольф': 1,
#   'майк': 2,
#   'лиз': 1,
#   'элвный': 1,
#   'кивайко': 1,
#   'мик': 1,
#   'бедо': 1,
#   'джекман': 1,
#   'дэдпул': 1,
#   'хемсворт': 1,
#   'хиддлстон': 1,
#   'радда': 1,
#   'руффало': 1,
#   'росомаха': 1,
#   'тор': 1,
#   'олсена': 1,
#   'халк': 2,
#   'суиня': 1,
#   'коулмить': 1,
#   'нгай': 1,
#   'таунсенд': 2,
#   'сабла': 1,
#   'наполеон': 1,
#   'эррера': 1,
#   'трейся': 1,
#   'краутхаммер': 1,
#   'агирр': 1,
#   'фернандес': 1,
#   'цукерберг': 3,
#   'арчибонг': 1,
#   'картер': 1,
#   'холт': 1,
#   'риттер': 1,
#   'кейдж': 1,
#   'этвелла': 1,
#   'жирачкова': 1,
#   'венить': 1,
#   'пэрис': 1,
#   'барби': 2,
#   'микаэл': 1,
#   'наанай': 1,
#   'мираклентина': 1,
#   'нанай': 1,
#   'азубуик': 1,
#   'рубино': 1,
#   'хой': 1,
#   'бэррон': 1,
#   'гилберт': 1,
#   'малск': 1,
#   'хасан': 5,
#   'алиев': 2,
#   'усоян': 5,
#   'спайдермен': 1,
#   'стюарт': 1,
#   'слайсер': 1,
#   'i': 3,
#   'хагстрем': 1,
#   'обрайен': 1,
#   'хэйуард': 2,
#   'келлен': 1,
#   'гиббинс': 1,
#   'гефтер': 2,
#   'логуа': 1,
#   'гальский': 3,
#   'ахвледиани': 1,
#   'сухумский': 3,
#   'убилава': 1,
#   'батумский': 1,
#   'абрахам': 1,
#   'эмили': 1,
#   'ратаковск': 3,
#   'максим': 1,
#   'драммонд': 1,
#   'аль-авади': 1,
#   'лю': 2,
#   'родченков': 1,
#   'зеппельт': 1,
#   'штайнмайер': 1,
#   'хорн': 1,
#   'марчиано': 1,
#   'аптон': 2,
#   'йовин': 1,
#   'жакмя': 1,
#   'корсаков': 1,
#   'хадид': 2,
#   'korsakova': 1,
#   'elias': 1,
#   'smyrniotaki': 1,
#   'сэм': 1,
#   'мари': 1,
#   'марь': 1,
#   'фаномрат': 1,
#   'саманамуд': 1,
#   'айлендс': 1,
#   'ховард': 1,
#   'сехера': 1,
#   'асгар': 1,
#   'тенети': 1,
#   'макрон': 3,
#   'бейтс': 2,
#   'капур': 1,
#   'сено': 1,
#   'сен': 1,
#   'иванка': 2,
#   'пистоль': 1,
#   'миранда': 1,
#   'полстон': 1,
#   'торрес': 2,
#   'мармолехо': 1,
#   'кристиансен': 1,
#   'михельб': 1,
#   'буфьера': 1,
#   'меркель': 2,
#   'зеехофер': 1,
#   'харман': 1,
#   'блаттер': 1,
#   'инфантино': 1,
#   'маллиган': 1,
#   'дэйнс': 1,
#   'вайс': 1,
#   'блант': 1,
#   'скоттен': 1,
#   'виелка': 1,
#   'вилок': 1,
#   'олененок': 1,
#   'бауэр': 1,
#   'джинджер': 1,
#   'мо': 1,
#   'глик': 1,
#   'толунай': 1,
#   'пейрсон': 1,
#   'чаблоза': 1,
#   'зани': 1,
#   'тиба': 1,
#   'найджела': 1,
#   'сара': 3,
#   'лайонс': 1,
#   'гудман': 2,
#   'хагенс': 1,
#   'несси': 1,
#   'геммел': 1,
#   'истон': 1,
#   'согласиться': 1,
#   'маккоркодейл': 3,
#   'диана': 5,
#   'вудхаус': 3,
#   'туллекен': 1,
#   'эллиотт': 1,
#   'салас': 2,
#   'хардвик': 1,
#   'дикстра': 1,
#   'чоп': 2,
#   'рис': 1,
#   'пеннингтон': 1,
#   'пыз': 1,
#   'шонии': 1,
#   'парпалия': 2,
#   'форд': 1,
#   'кейн': 2,
#   'полер': 1,
#   'полера': 1,
#   'флепс': 1,
#   'сью': 3,
#   'фред': 3,
#   'саманта': 2,
#   'сантос': 1,
#   'кортани': 1,
#   'тавеккио': 1,
#   'кортаня': 1,
#   'бордвелла': 1,
#   'самуэль': 1,
#   'денс': 1,
#   'лейла': 1,
#   'мерикосок': 1,
#   'паркер': 1,
#   'фуллертон': 2,
#   'пеньяо': 1,
#   'рамон': 1,
#   'браунесса': 1,
#   'теран': 4,
#   'лесли': 3,
#   'заметить': 1,
#   '.': 2,
#   'доусон': 1,
#   'малкольм': 1,
#   'гранье': 1,
#   'тинтагель': 1,
#   'артур': 1,
#   'айклера': 1,
#   'ишервуд': 1,
#   'бек': 2,
#   'хайд': 1,
#   'фуд-блогер': 1,
#   'брокколи': 1,
#   'вона': 2,
#   'хупер': 1,
#   'хаббла': 1,
#   'дайсон': 1,
#   'хартманн': 1,
#   'помпео': 1,
#   'льюин': 1,
#   'афродита': 1,
#   'кнудсен': 1,
#   'йонас': 1,
#   'сальвадор': 1,
#   'милон': 1,
#   'батори': 1,
#   'костница': 1,
#   'эггенбургский': 1,
#   'апскертинг': 1,
#   'мэй': 3,
#   'магдалена': 1,
#   'джоля': 2,
#   'мэддоу': 1,
#   'гофф': 1,
#   'браун': 4,
#   'айла': 1,
#   'крессуэла': 1,
#   'джошуа': 1,
#   'гросс': 1,
#   'хохшильд': 1,
#   'американец': 1,
#   'маквэя': 1,
#   'триппа': 1,
#   'маск': 3,
#   'трипп': 1,
#   'андреа': 1,
#   'логан': 1,
#   'алекс': 1,
#   'элли': 1,
#   'ресинг': 1,
#   'палмери': 2,
#   'реотья': 2,
#   'киммел': 3,
#   'грейдон': 1,
#   'мильнер': 1,
#   'смит': 7,
#   'мэйер': 1,
#   'хла': 1,
#   'изабелла': 1,
#   'чэпел': 1,
#   'везунчик': 1,
#   'чэпэла': 1,
#   'халка': 1,
#   'греннан': 1,
#   'джордан': 2,
#   'джексон': 3,
#   'ковач': 1,
#   'коулман': 1,
#   'бегент': 1,
#   'фридланда': 1,
#   'коллинза': 6,
#   'нойер': 1,
#   'альварес': 1,
#   'фоллстад': 1,
#   'кьендли': 1,
#   'косян': 1,
#   'ивановский': 1,
#   'мкртчян': 1,
#   'ереванский': 1,
#   'мегана': 1,
#   'арбитер': 1,
#   'ротема': 1,
#   'чехов': 1,
#   'моун': 1,
#   'массеть': 1,
#   'гимарейс': 1,
#   'конуэй': 1,
#   'gambino': 1,
#   'гловер': 2,
#   'харли': 2,
#   'лоу': 3,
#   'атертон': 1,
#   'стаддард': 1,
#   'стоддард': 1,
#   'мичико': 1,
#   'тимофеев': 1,
#   'аббясов': 1,
#   'коган': 1,
#   'нилов': 1,
#   'бендас': 1,
#   'нил': 1,
#   'purrslevich': 1,
#   'сагал': 3,
#   'сурвейза': 1,
#   'лаура': 1,
#   'абернать': 1,
#   'фэрримонд': 1,
#   'прайс': 1,
#   'нур': 1,
#   'хусейн': 1,
#   'хуссейн': 1,
#   'уотсон': 1,
#   'кэмпбелл': 2,
#   'окамото': 1,
#   'няшин': 1,
#   'hagex': 1,
#   'уордлый': 1,
#   'уордло': 1,
#   'сакаран': 1,
#   'мирс': 1,
#   'хайгл': 1,
#   'сэлисбари': 1,
#   'скиннер': 1,
#   'эгня': 1,
#   'кейт': 2,
#   'рэдклифф': 1,
#   'перон': 1,
#   'феррагамо': 1,
#   'монро': 1,
#   'мэдисон': 1,
#   'сэбби-стремпел': 1,
#   'да': 1,
#   'caroline': 1,
#   'ок': 1,
#   'мур': 2,
#   'олер': 1,
#   'блэкмор': 1,
#   'салман': 1,
#   'рифай': 1,
#   'бобби': 1,
#   'тони': 2,
#   'мина': 1,
#   'пермана': 2,
#   'маска': 2,
#   'прэнк': 1,
#   'гордон': 1,
#   'хейворд': 1,
#   'арбакл': 1,
#   'еж': 1,
#   'толстяк': 1,
#   'фриман': 1,
#   'кук': 3,
#   'рамос': 2,
#   'фелич': 1,
#   'круз': 1,
#   'блэк': 1,
#   'вюссе': 1,
#   'комиск': 1,
#   'пин-код': 1,
#   'ямагуч': 1,
#   'ито': 1,
#   'тахан': 1,
#   'мейсон': 1,
#   'даффи': 1,
#   'нойманна': 1,
#   'бузакка': 1,
#   'грабитель-рецидивист': 1,
#   'фаида': 2,
#   'огунгбесан': 1,
#   'эйвон': 1,
#   'шекарч': 1,
#   'убейд': 1,
#   'аль-абади': 1,
#   'танк': 1,
#   'фаид': 1,
#   'устать': 1,
#   'галаксиа': 1,
#   'тодда': 1,
#   'тоддом': 1,
#   'рабьо': 1,
#   'абэ': 1,
#   'ментцер': 1,
#   'гомес': 3,
#   'шаффера': 1,
#   'ириска': 1,
#   'тиффаня': 1,
#   'вайнштейн': 1,
#   'би': 1,
#   'вульф': 1,
#   'сандерс': 4,
#   'мейплзти': 1,
#   'рана': 1,
#   'ран': 1,
#   'мермельштайн': 1,
#   'мермельштайна': 1,
#   'таулапапа': 1,
#   'надин': 1,
#   'кайло': 1,
#   'кайла': 2,
#   'дельтор': 1,
#   'хьюстон': 1,
#   'рикардссон': 1,
#   'хитон': 1,
#   'зак': 1,
#   'дональдсон': 1,
#   'консонни': 1,
#   'джалали': 1,
#   'нкала': 1,
#   'сибанда': 1,
#   'скотт': 1,
#   'гарсия': 1,
#   'pump': 2,
#   'фурние': 1,
#   'хэндлера': 1,
#   'хилтон': 1,
#   'назарбаев': 1,
#   'шкрум': 1,
#   'софия': 1,
#   'шакир': 2,
#   'финч': 1,
#   'бейль': 2,
#   'джосса': 1,
#   'уэстбрук': 1,
#   'соведущий': 1,
#   'дайер': 1,
#   'бренд': 1,
#   'сакс': 1,
#   'джек': 3,
#   'талли': 1,
#   'босс': 1,
#   'фишер': 2,
#   'моккус': 1,
#   'лав': 1,
#   'крэггс': 1,
#   'бор-бор': 1,
#   'американка': 1,
#   'ерс': 1,
#   'падрон': 1,
#   'фуцюня': 1,
#   'локханда': 1,
#   'наблюдать': 1,
#   'торбик': 1,
#   'мусазада': 1,
#   'мусазад': 1,
#   'барон': 1,
#   'мейзел': 1,
#   'латиф': 1,
#   'мидзухара': 1,
#   'новый': 1,
#   'грант': 2,
#   'сяотун': 1,
#   'палау': 1,
#   'сюй': 1,
#   'макграт': 1,
#   'виверс': 1,
#   'шераз': 1,
#   'ясин': 1,
#   'уайтхаус': 1,
#   'сунарсиха': 1,
#   'окум': 1,
#   'кэрен': 1,
#   'лекси': 1,
#   'лиланда': 1,
#   'огненовск': 1,
#   'коннор': 1,
#   'андерсон': 1,
#   'коннора': 1,
#   'абло': 1,
#   'аарон': 1,
#   'гиббонс': 1,
#   'вардлый': 1,
#   'туазон': 1,
#   'пейтон': 1,
#   'барнс': 1,
#   'хейс': 1,
#   'студент-медик': 1,
#   'эдвард': 1,
#   'перри': 1,
#   'видеопрокат': 1,
#   'михельс': 1,
#   'руставский': 2,
#   'асанидзе': 1,
#   'шукакидзе': 1,
#   'шушанашвили': 5,
#   'глданский': 1,
#   'панпалия': 1,
#   'раджа': 1,
#   'денить': 1,
#   'моррис': 1,
#   'ву': 4,
#   'харлоу': 1,
#   'молли': 1,
#   'монь': 1,
#   'мел': 1,
#   'чудо-милль': 1,
#   'мила': 1,
#   'мэри': 2,
#   'мелли': 1,
#   'мими': 1,
#   'минь': 1,
#   'мулана': 1,
#   'семлер': 1,
#   'малли': 1,
#   'милль': 1,
#   'мум': 1,
#   'гэмбла': 1,
#   'лях': 1,
#   'скрепер': 1,
#   'блум': 1,
#   'эдвардс': 1,
#   'тарасов': 1,
#   'акинфей': 1,
#   'серф': 1,
#   'брайен': 1,
#   'дерипаска': 3,
#   'кириллов': 1,
#   'рыбка': 2,
#   'стрэндже': 1,
#   'ли': 3,
#   'дитко': 1,
#   'октопус': 1,
#   'гоблин': 1,
#   'ачкар': 1,
#   'маэда': 1,
#   'гимнастка': 1,
#   'мухамедьянов': 1,
#   'гилдинг': 1,
#   'рукундо': 1,
#   'като': 1,
#   'лоно': 1,
#   'маленький': 1,
#   'аллах': 1,
#   'майя': 1,
#   'мохаммед': 1,
#   'дормер': 1,
#   'тирелла': 1,
#   'ричардсон': 1,
#   'обнаженка': 1,
#   'скрейн': 1,
#   'космо': 1,
#   'бирн': 1,
#   'райт': 3,
#   'алпаидзе': 1,
#   'джангвеладзе': 2,
#   'салиф': 2,
#   'мераб': 1,
#   'александр': 1,
#   'биг-маков': 1,
#   'горск': 1,
#   'рианна': 2,
#   'минаж': 1,
#   'тео': 1,
#   'пух': 2,
#   'оливер': 2,
#   'цзиньпин': 1,
#   'яоцюн': 1,
#   'кац': 1,
#   'канди': 1,
#   'жиньяк': 2,
#   'саффера': 1,
#   'саффер': 2,
#   'прахапат': 1,
#   'бекка': 1,
#   'кавано': 1,
#   'коуэлла': 1,
#   'уолш': 1,
#   'ресио': 1,
#   'кубока': 1,
#   'заруцк': 1,
#   'усатый': 1,
#   'достоевский': 1,
#   'сэдлер': 1,
#   'биггерс': 1,
#   'чеп': 1,
#   'мундлос': 1,
#   'бенхардт': 1,
#   'бофа': 1,
#   'телепнев': 2,
#   'ширман': 2,
#   'ванкевич': 2,
#   'тимати': 2,
#   'бруншота': 1,
#   'бруншот': 1,
#   'ся': 1,
#   'дуаня': 1,
#   'иванов': 1,
#   'хэюня': 1,
#   'элоиза': 1,
#   'итан': 1,
#   'моретон': 1,
#   'жириновский': 1,
#   'грудинин': 1,
#   'бишоп': 1,
#   'хэмптон': 1,
#   'перес': 2,
#   'паркинсон': 1,
#   'чиллал': 1,
#   'singh': 1,
#   'дин': 1,
#   'рэймонд': 1,
#   'туллио': 1,
#   'бэмфорд': 1,
#   'велаять': 1,
#   'хаменея': 1,
#   'юнг': 1,
#   'садель': 1,
#   'кутаисский': 1,
#   'дзнеладзе': 1,
#   'колокольцев': 2,
#   'станиславский': 1,
#   'молодой': 6,
#   'сазарст': 1,
#   'гарт': 1,
#   'шарлотта': 1,
#   'уоттс': 1,
#   'фьюри': 1,
#   'тарантино': 1,
#   'джулс': 1,
#   'кирби': 1,
#   'авенатти': 2,
#   'клиффорда': 2,
#   'клиффорд': 2,
#   'дэниелс': 1,
#   'конрад': 1,
#   'харви': 1,
#   'мессер': 1,
#   'глив': 1,
#   'лири': 1,
#   'британец': 1,
#   'роулинга': 1,
#   'поттер': 1,
#   'депп': 1,
#   'шиа': 1,
#   'редмэйн': 1,
#   'дамблдор': 1,
#   'саламандер': 1,
#   'хейль': 2,
#   'сидней': 1,
#   'чарли': 1,
#   'наберхаус': 1,
#   'кавьер': 1,
#   'гаспар': 1,
#   'встречать': 1,
#   'клегга': 1,
#   'лагер': 1,
#   'кэмерон': 1,
#   'деннис': 1,
#   'тейлор': 2,
#   'бурра': 1,
#   'ландстедт': 1,
#   'реичл': 1,
#   'рангил': 1,
#   'дэн': 1,
#   'лобба': 1,
#   'иларион': 1,
#   'эшлиманн': 1,
#   'брандт': 1,
#   'маас': 1,
#   'ngawaero': 1,
#   'сугито': 1,
#   'хоук': 1,
#   'брамстон': 1,
#   'коран': 1,
#   'мэддисон': 1,
#   'рейд': 1,
#   'миллинера': 1,
#   'гошалый': 1,
#   'гошала': 1,
#   'ансворт': 1,
#   'грабар-китарович': 1,
#   'китарович': 1,
#   'теобальд': 1,
#   'теобалед': 1,
#   'ленин': 2,
#   'мартинез': 1,
#   'фаранд': 1,
#   'триоль': 1,
#   'вирджиния': 1,
#   'томсон': 1,
#   'брейли': 1,
#   'баннер': 1,
#   'бэннер': 1,
#   'буш-старший': 1,
#   'ной': 1,
#   'эрдогла': 2,
#   'зек': 1,
#   'гюлен': 2,
#   'инан': 2,
#   'игит': 2,
#   'хелсон': 1,
#   'познер': 1,
#   'бутин': 3,
#   'юсуф': 1,
#   'ягуар': 1,
#   'бергдорф': 1,
#   'маккерет': 1,
#   'модель-трансгендер': 1,
#   'манро': 1,
#   'валетуда': 1,
#   'валетуд': 1,
#   'бэрфорд': 1,
#   'невилл': 1,
#   'омар': 1,
#   'довидавичус': 1,
#   'норейка': 1,
#   'фоть': 1,
#   'ветер': 1,
#   'руттенауэр': 1,
#   'торшин': 2,
#   'задержать': 1,
#   'татьяна': 1,
#   'уолшоу': 1,
#   'каликсто': 1,
#   'бумбум': 1,
#   'фуртадо': 1,
#   'кулаков': 1,
#   'карра': 1,
#   'впечатлить': 1,
#   'ричард': 1,
#   'клифф': 1,
#   'печенька': 1,
#   'yachty': 2,
#   'мэк': 1,
#   'jay-z': 1,
#   'дешам': 1,
#   'манджукич': 1,
#   'донован': 1,
#   'уилсон': 2,
#   'сяоля': 1,
#   'сяоль': 1,
#   'роу': 2,
#   'нильсенов': 1,
#   'итальянец': 2,
#   'дрыманов': 3,
#   'крамаренко': 3,
#   'максименко': 3,
#   'калашов': 2,
#   'никандров': 3,
#   'кочуйков': 2,
#   'ламонов': 3,
#   'бадди': 1,
#   'джотема': 1,
#   'веганский': 1,
#   'вудкок': 1,
#   'шереметев': 1,
#   'дерипаск': 1,
#   'вашукевич': 1,
#   'черножуков': 1,
#   'октавия': 1,
#   'карли': 1,
#   'хопкинс': 1,
#   'рэтчед': 1,
#   'пристля': 1,
#   'ланда': 1,
#   'лукас': 1,
#   'вейдер': 1,
#   'уивинг': 1,
#   'николсон': 2,
#   'хэмилтон': 1,
#   'лектер': 1,
#   'стрип': 1,
#   'проуз': 1,
#   'халиль': 2,
#   'иисус': 1,
#   'мэнчон': 1,
#   'уорхол': 1,
#   'чарлзти': 1,
#   'стил': 1,
#   'хиллблом': 1,
#   'хиллбрум': 1,
#   'кинни': 1,
#   'ульбрихт': 1,
#   'anarchy': 1,
#   'анубхав': 1,
#   'отравиться': 1,
#   'стерджесс': 1,
#   'роули': 1,
#   'саймон': 1,
#   'макдональд': 1,
#   'шитс': 1,
#   'серный': 1,
#   'флеминг': 1,
#   'хробовск': 1,
#   'махер': 1,
#   'вустер': 1,
#   'страйк': 1,
#   'кэри': 1,
#   'зарнецк': 1,
#   'краун': 1,
#   'лофтоссон': 1,
#   'финвал': 1,
#   'лофтссон': 1,
#   'баррос': 1,
#   'паредес': 1,
#   'игер': 1,
#   'коротышка': 3,
#   'гилана': 1,
#   'эми': 1,
#   'кой': 1,
#   'лу': 1,
#   'рыболов': 1,
#   'гаркак': 1,
#   'табар': 1,
#   'лонг': 1,
#   'инвидиат': 1,
#   'самсон': 1,
#   'тимоти': 1,
#   'дрейк': 2,
#   'терня': 1,
#   'сэвидж': 1,
#   'адкин': 1,
#   ...},
#  'кнышов': {'су-57': 1, 'летчик-испытатель': 1, 'толбоев': 1},
#  'су-57': {'кнышов': 1,
#   'летчик-испытатель': 1,
#   'толбоев': 3,
#   'оликер': 1,
#   'шойгу': 2,
#   'подвиг': 1,
#   'купер': 1,
#   'криворучко': 1,
#   'гутенев': 1,
#   'бронк': 1,
#   'борисов': 3,
#   'роблин': 1,
#   'тревитик': 1,
#   'кудрявцев': 1,
#   'слюсарь': 2,
#   'миг-41': 1,
#   'бондарев': 1,
#   'тарасенко': 1},
#  'летчик-испытатель': {'кнышов': 1, 'су-57': 1, 'толбоев': 1, 'квочура': 1},
#  'толбоев': {'кнышов': 1,
#   'су-57': 3,
#   'летчик-испытатель': 1,
#   'оликер': 1,
#   'шойгу': 1,
#   'подвиг': 1,
#   'купер': 1},
#  'воробьев': {'витолиньша': 1,
#   'федосов': 1,
#   'знарк': 2,
#   'знарок': 1,
#   'тресковый': 4,
#   'дитрих': 1,
#   'путин': 9,
#   'марков': 7,
#   'ваммис': 1,
#   'тагий': 11,
#   'кузнецов': 1,
#   'стасишин': 1,
#   'плутник': 1,
#   'ниденс': 1,
#   'фаевский': 4,
#   'пест': 5,
#   'петипа': 1,
#   'сен-санс': 1,
#   'бертман': 1,
#   'латам-кениг': 1,
#   'башмет': 1,
#   'хаматов': 1,
#   'макрон': 1,
#   'меньшиков': 1,
#   'чайковский': 1,
#   'мацуев': 1,
#   'ширалиев': 1,
#   'радаев': 1,
#   'усс': 1,
#   'сечин': 1,
#   'патрушев': 1,
#   'коков': 1,
#   'коган': 3,
#   'хуснуллин': 1,
#   'собянин': 12,
#   'ефремов': 1,
#   'дворкович': 1,
#   'хаймурзин': 2,
#   'роман': 1,
#   'юриевич': 2,
#   'валентина': 1,
#   'андрей': 1,
#   'лысенко': 1,
#   'александр': 1,
#   'костомаров': 1,
#   'кабанов': 1,
#   'близнюк': 1,
#   'рогов': 1,
#   'чикать': 1,
#   'борисюк': 1,
#   'абянов': 1,
#   'монсон': 3,
#   'хромушин': 4,
#   'бойко': 1,
#   'рабинович': 1,
#   'семенович': 1,
#   'медведев': 2,
#   'шойгу': 2,
#   'матвиенко': 1,
#   'володин': 1,
#   'ювеналий': 2,
#   'никита': 1,
#   'даниил': 1,
#   'татьяна': 1,
#   'мороз': 1,
#   'шведов': 1,
#   'брынцалов': 4,
#   'буцаев': 3,
#   'захаров': 6,
#   'забралов': 6,
#   'чичек': 1,
#   'полупан': 1,
#   'никольский': 1,
#   'тюрин': 1,
#   'полетыкин': 1,
#   'чистюхин': 1,
#   'надеждин': 1,
#   'мособлизбирком': 1,
#   'ан': 2,
#   'борисов': 1,
#   'посаженник': 1,
#   'лебедев': 1,
#   'разин': 9,
#   'гордеев': 1,
#   'матвейчев': 1,
#   'какурин': 1,
#   'кормухин': 1,
#   'пушкин': 1,
#   'серов': 1,
#   'печенегин': 1,
#   'майдан': 1,
#   'юденич': 1,
#   'губерний': 1,
#   'огурцов': 1,
#   'маликов': 1,
#   'легков': 1,
#   'кончаловский': 1,
#   'камаева': 1,
#   'кирилл': 1,
#   'рябов': 1,
#   'барсуков': 1,
#   'якушев': 1,
#   'юров': 1,
#   'кобылкин': 1,
#   'расулмухамед': 1,
#   'сирота': 1,
#   'терюшков': 3,
#   'каменский': 1,
#   'малкин': 1,
#   'пестово': 1,
#   'акинфеев': 1},
#  'витолиньша': {'воробьев': 1, 'федосов': 1, 'знарк': 1, 'знарок': 1},
#  'федосов': {'воробьев': 1, 'витолиньша': 1, 'знарк': 1, 'знарок': 1},
#  'знарк': {'воробьев': 2, 'витолиньша': 1, 'федосов': 1, 'знарок': 1},
#  'знарок': {'воробьев': 1, 'витолиньша': 1, 'федосов': 1, 'знарк': 1},
#  'васильев': {'иванов': 1,
#   'путин': 4,
#   'запорожский': 1,
#   'шейнин': 1,
#   'абдулатипов': 1,
#   'алиев': 1,
#   'гамидов': 1,
#   'усов': 1,
#   'сердюков': 3,
#   'пузиков': 1,
#   'эдуардович': 2,
#   'малахов': 2,
#   'бушуев': 1,
#   'белых': 2,
#   'трунов': 1,
#   'екатерина': 1,
#   'юриевич': 1,
#   'лемар': 1,
#   'головин': 3,
#   'мбапп': 1,
#   'аршавин': 1,
#   'силва': 1,
#   'жирков': 1,
#   'сергеев': 1,
#   'камин': 1,
#   'михальченко': 1,
#   'строганов': 1,
#   'синюгин': 3,
#   'лихунов': 1,
#   'оводовый': 1,
#   'рощин': 1,
#   'татьяна': 1,
#   'кузьменко': 1,
#   'кисловодск': 1,
#   'калинкин': 1,
#   'варченко': 1,
#   'корючин': 1,
#   'гусев': 1,
#   'ванеев': 1,
#   'ильинов': 1,
#   'бегун': 1,
#   'степанов': 1,
#   'мамонтов': 1,
#   'коршунов': 1,
#   'бойко': 1,
#   'якушев': 1,
#   'владимирович': 1,
#   'матовник': 1,
#   'сорокин': 1,
#   'кириенко': 1},
#  'иванов': {'васильев': 1,
#   'герман': 1,
#   'бабченко': 1,
#   'луценко': 1,
#   'пашаев': 1,
#   'медведев': 1,
#   'глухов': 1,
#   'матюшкин': 1,
#   'страсбургский': 1,
#   'бровкий': 1,
#   'ципрас': 1,
#   'заев': 2,
#   'богданов': 1,
#   'свердлов': 1,
#   'альцгеймер': 1,
#   'абубакар': 1,
#   'кадыров': 1,
#   'бедрицкий': 1,
#   'эдельгерий': 1,
#   'эдельгериев': 1,
#   'путин': 4,
#   'караулов': 1,
#   'будайханов': 1,
#   'хуторянин': 1,
#   'черных': 1,
#   'валихидис': 1,
#   'кусакина': 1,
#   'кольченко': 1,
#   'высоцкий': 2,
#   'одинцов': 1,
#   'ковалиса': 1,
#   'гречин': 2,
#   'нефедов': 1,
#   'агеев': 2,
#   'седина': 1,
#   'гриб': 1,
#   'доронин': 2,
#   'сущенко': 1,
#   'сидоров': 2,
#   'макаров': 1,
#   'шаталов': 2,
#   'сенцов': 2,
#   'геращенко': 1,
#   'егоров': 1,
#   'панов': 1,
#   'гаджиев': 1,
#   'сливка': 1,
#   'денисов': 2,
#   'бусыгин': 1,
#   'кемаковский': 1,
#   'баранов': 1,
#   'чубаров': 1,
#   'балух': 1,
#   'грат': 1,
#   'ламбурт': 1,
#   'акинфеев': 1,
#   'карпинского-1': 1,
#   'орлов': 1,
#   'акинфей': 1,
#   'фаррадж': 1,
#   'бэннон': 1,
#   'бэнкса': 1,
#   'трамп': 1,
#   'бэнкс': 1,
#   'яковенко': 1,
#   'салихина': 1,
#   'богдановский': 1,
#   'ионов': 1,
#   'гречка': 3,
#   'уэйлс': 1,
#   'столтенберг': 1,
#   'ся': 1,
#   'дуаня': 1,
#   ')': 1,
#   'хэюня': 1,
#   'саввиди': 1,
#   'елкан': 1,
#   'булавинцев': 1,
#   'тоноян': 1,
#   'елканов': 1,
#   'саруханян': 1,
#   'пашинянин': 1,
#   'арбенин': 1,
#   'земфира': 2,
#   'монеточка': 2,
#   'гырдымов': 2,
#   'поболтать': 1,
#   'дудь': 1,
#   'шойгу': 2,
#   'мель': 1,
#   'линкявичюс': 1,
#   'калимулай': 1,
#   'калимулаев': 1,
#   'ермолаев': 1,
#   'саакашвили': 1,
#   'шнур': 1,
#   'владимирович': 1,
#   'шпак': 1,
#   'рачук': 1,
#   'петросян': 1,
#   'ваганович': 1,
#   'жорин': 1,
#   'степаненко': 1,
#   'елена': 1,
#   'валехидис': 1,
#   'саттар': 1,
#   'камал': 1,
#   'седиков': 1,
#   'кудрявцев': 1,
#   'акимов': 1,
#   'хьюард': 1},
#  'порошенко': {'григоренко': 1,
#   'геращенко': 1,
#   'путин': 18,
#   'тимофеев': 1,
#   'захарченко': 1,
#   'савченко': 5,
#   'рубан': 4,
#   'никалавна': 1,
#   'ницой': 2,
#   'грицак': 1,
#   'бабченко': 1,
#   'столтенберг': 5,
#   'расмуссен': 1,
#   'прокопов': 1,
#   'варфоломей': 3,
#   'сенцов': 4,
#   'вышинский': 3,
#   'хармс': 3,
#   'райан': 1,
#   'парубий': 2,
#   'гайдар': 2,
#   'белых': 2,
#   '.': 1,
#   'жебривский': 2,
#   'климкин': 6,
#   'бабин': 5,
#   'соболев': 2,
#   'денисов': 3,
#   'карпюк': 1,
#   'штыбликов': 1,
#   'москальков': 2,
#   'яровой': 1,
#   'князев': 1,
#   'ващук': 1,
#   'крищенко': 1,
#   'йованович': 1,
#   'эристави': 1,
#   'порошеко': 1,
#   'лев': 1,
#   'алексеевич': 2,
#   'челентано': 1,
#   'lions': 1,
#   'бессмертный': 1,
#   'пен': 1,
#   'бутусов': 1,
#   'дубинский': 2,
#   'турчин': 4,
#   'полторак': 4,
#   'роман': 1,
#   'гришин': 1,
#   'ротенберг': 2,
#   'борис': 1,
#   'памфилов': 1,
#   'никифоров': 1,
#   'аркадий': 1,
#   'булаево': 1,
#   'фирсов': 1,
#   'петр': 2,
#   'авак': 3,
#   'шишкин': 1,
#   'яценюк': 1,
#   'гройсман': 5,
#   'муженко': 2,
#   'волкер': 1,
#   'шабунин': 1,
#   'алтабаев': 2,
#   'трюдо': 2,
#   'воронченко': 1,
#   'вучича': 2,
#   'хан': 1,
#   'владимир': 3,
#   'тимошенко': 5,
#   'захаров': 1,
#   'лэйн': 1,
#   'гитлер': 1,
#   'шарий': 1,
#   'бирюков': 1,
#   'зинкевич': 1,
#   'турчинов': 1,
#   'коростелев': 1,
#   'трамп': 9,
#   'гриценко': 2,
#   'кравчук': 2,
#   'мосийчук': 2,
#   'гужва': 2,
#   'дуда': 1,
#   'бандера': 1,
#   'моравецкий': 1,
#   'вид': 2,
#   'вукоевич': 2,
#   'шуфрич': 2,
#   'насалик': 1,
#   'винник': 1,
#   'комаров': 1,
#   'коста': 1,
#   'макрон': 2,
#   'юнкер': 2,
#   'ткачев': 2,
#   'украина-нато': 1,
#   'хорват': 1,
#   'тук': 3,
#   'кличко': 1,
#   'эйнштейн': 1,
#   'ниро': 1,
#   'уэст': 1,
#   'достоевский': 1,
#   'лок': 3,
#   'гюлен': 1,
#   'инан': 1,
#   'эрдоган': 1,
#   'игит': 1,
#   'ан-178': 1,
#   'саша': 2,
#   'усик': 8,
#   'гассиев': 8,
#   'рябинский': 1,
#   'валуев': 1,
#   'омелян': 3,
#   'кириленко': 3,
#   'куприй': 1,
#   'грамоткин': 1,
#   'саджан': 1,
#   'петро': 1,
#   'вальцман': 1,
#   'корнелюк': 1,
#   'александров': 1,
#   'волошин': 1,
#   'ерофеев': 1,
#   'рубануть': 1,
#   'рубать': 1,
#   'луценко': 2,
#   'янукович': 1,
#   'макитра': 2,
#   'incognito': 1,
#   'косюк': 2,
#   'александр': 3,
#   'василевский': 1,
#   'гайдук': 2,
#   'джемилев': 2,
#   'сталин': 1,
#   'витренко': 2,
#   'фикс': 1,
#   'українь': 1,
#   'чубинский': 1,
#   'саакашвили': 1,
#   'юля': 1,
#   'танкер': 1,
#   'гданов': 1,
#   'крстулович-опара': 1,
#   'гурченко': 1,
#   'пирич': 1,
#   'марина': 3,
#   'пленкович': 1,
#   'пипкин': 1,
#   'галина': 1,
#   'гавриленко': 1,
#   'осовский': 1,
#   'pauluskp': 1,
#   'росовецкий': 1,
#   'томос': 1,
#   'глушков': 1,
#   'лопырева': 1,
#   'солженицын': 1,
#   'чикатить': 1,
#   'бондарь': 1,
#   'болтон': 2,
#   'медведев': 1,
#   'маккейн': 1,
#   'руснак': 1,
#   'пасхавер': 1,
#   'меркель': 1,
#   'казор': 1,
#   'гарсес': 1,
#   'гутерриш': 1,
#   'ельченко': 1,
#   'калашников': 1,
#   'климпуш-цинцадзе': 1,
#   'евгений': 2,
#   'алексей': 2,
#   'коболев': 1,
#   'супрун': 1,
#   'найем': 1,
#   'сыроид': 1,
#   'сытник': 1,
#   'александра': 1,
#   'береза': 1},
#  'григоренко': {'порошенко': 1},
#  'ласицкен': {'валлортигар': 1, 'демирева': 1},
#  'валлортигар': {'ласицкен': 1, 'демирева': 1},
#  'демирева': {'ласицкен': 1, 'валлортигар': 1},
#  'krizastro': {},
#  'лавров': {'ына': 13,
#   'трамп': 17,
#   'путин': 21,
#   'муалль': 3,
#   'ын': 13,
#   'киселев': 2,
#   'обама': 1,
#   'ыну': 3,
#   'песков': 2,
#   'меламед': 1,
#   'мустафина': 1,
#   'иной': 3,
#   'цзиньпин': 3,
#   'нам': 2,
#   'олбрайт': 1,
#   'ратников': 1,
#   'джонсон': 2,
#   'мэй': 1,
#   'даллес': 1,
#   'тэтчер': 1,
#   'уолд': 1,
#   'паршев': 1,
#   'захаров': 5,
#   'корбина': 1,
#   'вейонис': 1,
#   'матвиенко': 1,
#   'тайсаев': 1,
#   'болтон': 3,
#   'ушаков': 3,
#   'пенс': 1,
#   'сноуден': 1,
#   'кеннеди': 1,
#   'ли': 1,
#   'дзанакопулос': 2,
#   'велаять': 1,
#   'фриганас': 1,
#   'герасимов': 1,
#   'кочарян': 1,
#   'хачатуров': 1,
#   'мнацаканян': 1,
#   'балаять': 1,
#   'неймар': 1,
#   'шойгу': 1,
#   'галузин': 1,
#   'онодэра': 1,
#   'коно': 1,
#   'райс': 1,
#   'саакашвили': 1,
#   'шаманов': 1,
#   'каныгин': 1,
#   'саркози': 1,
#   'скрипаля': 1,
#   'юлия': 1,
#   'ким': 1,
#   'вы': 1,
#   'меркель': 1,
#   'нойерт': 1,
#   'помпео': 2,
#   'хата': 1,
#   'асад': 2,
#   'айюб': 1,
#   'хаменей': 1,
#   'пригожин': 1,
#   'сорос': 1,
#   'муаллем': 1},
#  'ына': {'лавров': 13,
#   'трамп': 52,
#   'путин': 16,
#   'харрис': 1,
#   'чхоля': 5,
#   'ын': 45,
#   'ина': 4,
#   'асад': 1,
#   'киселев': 2,
#   'обама': 1,
#   'сик': 1,
#   'гак': 1,
#   'су': 1,
#   'ыну': 4,
#   'песков': 2,
#   'сандерс': 3,
#   'джулиани': 1,
#   'ким': 5,
#   'нам': 2,
#   'асмолов': 1,
#   'абэ': 3,
#   'алан': 1,
#   'икс': 1,
#   'гага': 1,
#   'олбрайт': 1,
#   'джордан': 1,
#   'сен': 1,
#   'снайдер': 1,
#   'ир': 1,
#   'ять': 1,
#   'меламед': 1,
#   'мустафина': 1,
#   'чжон': 2,
#   'болтон': 1,
#   'хантсман': 1,
#   'помпео': 6,
#   'хи': 1,
#   'климкин': 1,
#   'авак': 1,
#   'аваков': 1,
#   'ельцин': 1,
#   'сяньлун': 1,
#   'иной': 3,
#   'цзиньпин': 3,
#   'матвиенко': 1,
#   'тайсаев': 1,
#   'марклый': 1,
#   'чжу': 1,
#   'джонсон': 1,
#   'меган': 1,
#   'хей': 1,
#   'гарри': 1,
#   'миддлтон': 1,
#   'уильям': 1,
#   'джон': 1,
#   'морган': 1,
#   'вы': 1},
#  'трамп': {'лавров': 17,
#   'ына': 52,
#   'путин': 209,
#   'мальмстрем': 3,
#   'рид': 2,
#   'мелания': 20,
#   'ыну': 12,
#   'ын': 72,
#   'кардашьян': 4,
#   'джонсон': 11,
#   ')': 37,
#   'дэниэлс': 1,
#   'ким': 13,
#   'юнкер': 14,
#   'мюллер': 10,
#   'харрис': 2,
#   'чхоля': 5,
#   'эллисон': 1,
#   'кади': 1,
#   'сайн': 1,
#   'ти': 1,
#   'рок': 1,
#   'ять': 2,
#   'уэст': 3,
#   'оуэнс': 1,
#   'симмонс': 1,
#   'дэниелс': 2,
#   'хилла': 1,
#   'чейнза': 1,
#   'фабулос': 1,
#   'дуров': 1,
#   'навальный': 1,
#   'динаев': 1,
#   'мэй': 15,
#   'хантсман': 3,
#   'ушаков': 13,
#   'штрах': 2,
#   'ина': 3,
#   'асад': 6,
#   'нойерт': 5,
#   'трюдо': 8,
#   'кадлоу': 1,
#   'фриланда': 1,
#   'киселев': 1,
#   'обама': 26,
#   'сик': 1,
#   'гак': 1,
#   'су': 1,
#   'песков': 31,
#   'дэвис': 5,
#   'рейган': 4,
#   'аятолл': 1,
#   'хаменей': 2,
#   'хиллари': 1,
#   'клинтон': 23,
#   'эрнандес': 1,
#   'гуахарадо': 1,
#   'кортни': 1,
#   'уилсон': 1,
#   'шамдасаня': 1,
#   'бэккер': 1,
#   'каффера': 1,
#   'каффер': 1,
#   'сандерс': 23,
#   'талиб': 1,
#   'али': 2,
#   'мирходжа': 1,
#   'рахмон': 1,
#   'христос': 1,
#   'иисус': 1,
#   'мария': 2,
#   'солнце': 1,
#   'цзиньпин': 8,
#   'марьям': 1,
#   'салех': 1,
#   'девараджан': 1,
#   'нетаньяху': 2,
#   'бисмарк': 1,
#   'макрон': 11,
#   'диллон': 2,
#   'мэр': 3,
#   'ле': 2,
#   'помпео': 29,
#   'мнучин': 7,
#   'могериня': 2,
#   'элис': 1,
#   'джулиани': 3,
#   'нам': 2,
#   'асмолов': 1,
#   'абэ': 6,
#   'трамп-король': 1,
#   'пеп': 1,
#   'курец': 8,
#   'курц': 2,
#   'салман': 2,
#   'маас': 8,
#   'овечкин': 3,
#   'меркель': 22,
#   'пресли': 1,
#   'мадалить': 1,
#   'конт': 6,
#   'алан': 1,
#   'икс': 1,
#   'туск': 4,
#   'гага': 1,
#   'рябок': 2,
#   'сэдлера': 1,
#   'хаспеть': 1,
#   'маккейн': 15,
#   'олбрайт': 1,
#   'джордан': 1,
#   'сен': 1,
#   'снайдер': 1,
#   'ир': 1,
#   'брилев': 1,
#   'гриффин': 2,
#   'янукович': 7,
#   'килимник': 2,
#   'манафорт': 17,
#   'чжон': 2,
#   'болтон': 35,
#   'уигмор': 1,
#   'бэннон': 3,
#   'бэнкса': 2,
#   'бэнкс': 2,
#   'уигмором': 1,
#   'яковенко': 2,
#   'хи': 1,
#   'спрингстин': 2,
#   'ниро': 3,
#   'климкин': 3,
#   'авак': 1,
#   'аваков': 2,
#   'ельцин': 1,
#   'doranimated': 1,
#   'кушнер': 4,
#   'иванка': 5,
#   'грэм': 4,
#   'пинчук': 1,
#   'макмастер': 2,
#   'вовк': 1,
#   'сяньлун': 1,
#   'ин': 1,
#   'шоу': 1,
#   'конфуций': 1,
#   'болдуин': 1,
#   'хазберг': 1,
#   'иной': 4,
#   'пистоль': 1,
#   'поклонской': 1,
#   'крым': 1,
#   'крафт': 1,
#   'коно': 1,
#   'безос': 1,
#   'безоса': 1,
#   'матвиенко': 1,
#   'тайсаев': 1,
#   'марклый': 1,
#   'мегана': 1,
#   'морган': 2,
#   'чарльз': 1,
#   'меган': 1,
#   'гарри': 1,
#   'гришэма': 3,
#   'полер': 1,
#   'полера': 1,
#   'мэттис': 6,
#   'орешкин': 3,
#   'хейль': 3,
#   'гарсиа': 1,
#   'кудрявцев': 1,
#   'маринченко': 1,
#   'конерц': 1,
#   'хартманн': 1,
#   'сешнс': 5,
#   'франциск': 1,
#   'римский': 2,
#   'бреммер': 1,
#   'шер': 1,
#   'корден': 1,
#   'маркиз': 1,
#   'апатоу': 1,
#   'хэндлера': 5,
#   'чавушогла': 1,
#   'эрдоган': 14,
#   'прюитта': 1,
#   'пруитта': 1,
#   'джексон': 3,
#   'рогозин': 1,
#   'шотвелла': 1,
#   'нильсен': 3,
#   'уилкинсон': 1,
#   'альварес': 1,
#   'столтенберг': 5,
#   'маккормик': 1,
#   'philipps': 1,
#   'vedder': 1,
#   'филиппс': 1,
#   'ортег': 1,
#   'уотерс': 2,
#   'макэлинэн': 1,
#   'макллрой': 1,
#   'хувен': 2,
#   'кеннеди': 6,
#   'шелбить': 2,
#   'митчелла': 4,
#   'бэндоу': 1,
#   'вайнштейн': 2,
#   'трамп-младший': 2,
#   'перлман': 1,
#   'донни': 1,
#   'хеллбой': 1,
#   'бюрен': 1,
#   'панахи': 1,
#   'роналда': 1,
#   'соуза': 1,
#   'хаменея': 1,
#   'рухани': 3,
#   'пенс': 9,
#   'дерипаска': 3,
#   'му': 1,
#   'ниинист': 6,
#   'черчесов': 1,
#   'фелич': 1,
#   'парубий': 3,
#   'миллер': 2,
#   'казанов': 1,
#   'сарандон': 1,
#   'паон': 1,
#   'грушко': 1,
#   'джахангиря': 1,
#   'коркоран': 1,
#   'дмитриев': 1,
#   'хук': 1,
#   'тиффаня': 1,
#   'би': 1,
#   'вульф': 1,
#   'мейплзти': 1,
#   'санчес': 2,
#   'фурние': 1,
#   'тиллерсон': 4,
#   'мадуро': 1,
#   'сантос': 1,
#   'окум': 1,
#   'бруно': 1,
#   'сагдиев': 1,
#   'аладин': 1,
#   'коэн': 11,
#   'джи': 1,
#   'ii': 10,
#   'хан': 2,
#   'джон': 4,
#   'турчинов': 1,
#   'коростелев': 1,
#   'порошенко': 9,
#   'байер': 1,
#   'бараско': 1,
#   'шаин': 1,
#   'волкер': 1,
#   'гидли': 1,
#   'фаррадж': 1,
#   'иванов': 1,
#   'ричардсон': 1,
#   'чуньин': 1,
#   'харрисон': 1,
#   'бекка': 1,
#   'кавано': 1,
#   'мишель': 2,
#   'филипп': 1,
#   'рейндерс': 1,
#   'хэтч': 1,
#   'лайтхайзер': 2,
#   'сергий': 1,
#   'герман': 2,
#   'стоунс': 1,
#   'михельсон': 1,
#   'тимченко': 1,
#   'алекперов': 1,
#   'радев': 1,
#   'шуфрич': 2,
#   'дубинин': 1,
#   'горбачев': 1,
#   'чейт': 1,
#   'буш': 7,
#   'скрипаля': 5,
#   'юлия': 3,
#   'царь-телефон': 1,
#   '(': 1,
#   'ахметов': 1,
#   'шифрин': 1,
#   'шнайдер': 1,
#   'бакай': 1,
#   'авенатти': 2,
#   'клиффорда': 4,
#   'клиффорд': 2,
#   'гройсман': 1,
#   'кирша': 1,
#   'скрипаль': 2,
#   'борис': 1,
#   'клегга': 1,
#   'лагер': 1,
#   'кэмерон': 1,
#   'садик': 1,
#   'аджао': 1,
#   'масуд': 1,
#   'козачек': 1,
#   'потемкин': 1,
#   'бадин': 1,
#   'нетыкшо': 1,
#   'малышев': 1,
#   'осадчук': 1,
#   'моргачев': 1,
#   'ковалев': 1,
#   'розенштейн': 1,
#   'антонов': 4,
#   'ершов': 1,
#   'лукашев': 1,
#   'ермаков': 1,
#   'белля': 2,
#   'чудовище': 1,
#   'аль-нахайян': 1,
#   'боровков': 1,
#   'копперойнен': 1,
#   'маккаллок': 1,
#   'тиммерманс': 1,
#   'хоук': 1,
#   'брамстон': 1,
#   'смирнов': 1,
#   'андреев': 1,
#   'датуна': 1,
#   'зариф': 3,
#   'коллинза': 2,
#   'протестовать': 1,
#   'бреннан': 2,
#   'келли': 2,
#   'кличко': 1,
#   'эйнштейн': 1,
#   'петр': 1,
#   'достоевский': 1,
#   'витренко': 3,
#   'антело': 1,
#   'симоньян': 1,
#   'трампович': 1,
#   'шварценеггер': 2,
#   'сипиль': 1,
#   'уоллес': 3,
#   'политковский': 1,
#   'немцов': 1,
#   'кинг': 1,
#   'буш-старший': 1,
#   'ной': 1,
#   'киммел': 3,
#   '2.0': 3,
#   'сэм': 1,
#   'джонстон': 1,
#   'джулия': 1,
#   'iv': 1,
#   'елизавета': 1,
#   'новак': 2,
#   'розенстайн': 1,
#   'владимирович': 1,
#   'карлсон': 1,
#   'шульц': 1,
#   'пауэлла': 2,
#   'мини-мы': 1,
#   'свифт': 1,
#   'гросс': 1,
#   'шахин': 1,
#   'баррасо': 1,
#   'костин': 1,
#   'бурсон': 1,
#   'гитлер': 1,
#   'макфол': 1,
#   'браудер': 1,
#   'поладить': 1,
#   'янг': 1,
#   'guccifer': 1,
#   'бонд': 1,
#   'коутс': 3,
#   'ил-96': 2,
#   'кернен': 2,
#   'лок': 1,
#   'геращенко': 2,
#   'маркис': 1,
#   'тук': 1,
#   'лагард': 2,
#   'макри': 1,
#   'николаев': 1,
#   'андрей': 1,
#   'бутин': 4,
#   'накасон': 3,
#   'брэр': 1,
#   'олсен': 1,
#   'марран': 1,
#   'ильвес': 1,
#   'юхтег': 1,
#   'олейник': 1,
#   'робертс': 3,
#   'менендес': 3,
#   'крэйн': 1,
#   'кэйден': 1,
#   'роухани': 1,
#   'орбан': 1,
#   'италиан': 1,
#   'киркпатрик': 1,
#   'джабар': 1,
#   'джабаров': 1,
#   'гонсалес': 1,
#   'баррассо': 3,
#   'сонненом': 1,
#   'емельяненко': 1,
#   'мир': 1,
#   'паттон': 1,
#   'дональд': 2,
#   'коллинс': 1,
#   'шина': 1,
#   'кейтлан': 1,
#   'сулеймани': 1,
#   'киссинджер': 1,
#   'брансон': 16,
#   'гюлен': 14,
#   'квинси': 1,
#   'карберри': 1,
#   'огустин': 1,
#   'нельсон': 1,
#   'тернбулла': 1,
#   'тревитик': 1,
#   'кодевилл': 1,
#   'хайтен': 1,
#   'ли': 1,
#   'рон': 1,
#   'коми': 2,
#   'драга': 1,
#   'харази': 1,
#   'мотахари': 1,
#   'фазли': 1,
#   'распутин': 1,
#   'мадд': 1,
#   'хэ': 1,
#   'ньето': 1,
#   'хэнкса': 1,
#   'спилберг': 1,
#   'кирк': 1,
#   'корнелюк': 1,
#   'александров': 1,
#   'волошин': 1,
#   'савченко': 1,
#   'ерофеев': 1,
#   'бауэрс': 1,
#   'уайт': 3,
#   'агалар': 2,
#   'агаларов': 2,
#   'балбер': 2,
#   'весельницкий': 4,
#   'эмин': 1,
#   'цукерберг': 1,
#   'хо': 1,
#   'рябков': 1,
#   'данфорд': 2,
#   'герасимов': 2,
#   'лорд': 1,
#   'рэй': 1,
#   'рей': 1,
#   'жирнов': 2,
#   'трампом-младший': 1,
#   'трампа-младший': 2,
#   'трамп-старший': 2,
#   'кудлоу': 1,
#   'арпайо': 2,
#   'джо': 1,
#   'мур': 2,
#   'кольбер': 1,
#   'хрущев': 1,
#   'пол': 1,
#   'медведев': 3,
#   'магнитский': 1,
#   'кардин': 1,
#   'гарднер': 1,
#   'замбия': 1,
#   'романовскиена': 1,
#   'сквернялис': 1,
#   'итконный': 1,
#   'макгрегор': 2,
#   'нурмагомедов': 2,
#   'нурмагомед': 2,
#   'науэрта': 1,
#   'уайлдс': 1,
#   'виктор': 1,
#   'кнавс': 1,
#   'фероли': 1,
#   'маниголт-ньюман': 4,
#   'библия': 1,
#   'албайрак': 1,
#   'вагенкнехт': 1,
#   'омароса': 1,
#   'никсон': 1,
#   'стайн': 1,
#   'форд': 1,
#   'рэмбо': 1,
#   'пейдж': 1,
#   'стрзок': 2,
#   'гольман': 1,
#   'хоровица': 1,
#   'модь': 1,
#   'шерман': 1,
#   'бальдерсон': 1,
#   'касич': 1,
#   'кольберт': 1,
#   'трахтенберг': 1,
#   'вы': 1,
#   'октай': 2,
#   'захаров': 2,
#   'кортун': 1,
#   'масся': 1,
#   'харт': 1,
#   'куомо': 1,
#   'берра': 1,
#   'яквинта': 1,
#   'хабиб': 1,
#   'абдулманап': 1,
#   'нурмагомедов-старший': 1,
#   'марч': 1,
#   'бруклин': 1,
#   'xiv': 1,
#   'мухаммед': 1,
#   'дриан': 1,
#   'холлен': 1,
#   'челик': 1,
#   'хант': 1,
#   'джимми': 2,
#   'спенсер': 1,
#   'апонт': 2,
#   'палия': 1,
#   'тодда': 1,
#   'тодд': 1,
#   'пауэлл': 1,
#   'вексельберг': 1,
#   'москальков': 1,
#   'магдугать': 2,
#   'данкан': 1,
#   'ирхарта': 1,
#   'патрушев': 1,
#   'сенатор': 1,
#   'блисс': 1,
#   'iii': 1,
#   'кадыров': 1,
#   'азар': 1,
#   'тиббеттс': 1,
#   'тиббетс': 1,
#   'сааведра': 1,
#   'лайонеть': 1,
#   'подест': 1,
#   'леброн': 1,
#   'синди': 1,
#   'кайло': 1,
#   'шадегга': 1,
#   'дьюся': 1,
#   'салмон': 1,
#   'маккейба': 1,
#   'байден': 1,
#   'кара-мурза': 1,
#   'файнголд': 1,
#   'кара-мурза-младший': 2,
#   'битти': 1,
#   'мантуров': 1,
#   'бортников': 1,
#   'греф': 1,
#   'роберта': 1,
#   'джонни': 1,
#   'пастор': 1,
#   'трамп-ребенок': 1,
#   'кисляк': 1},
#  'путин': {'лавров': 21,
#   'ына': 16,
#   'трамп': 209,
#   'голиков': 7,
#   'лок': 2,
#   'блок': 1,
#   'песков': 95,
#   'кудрявцев': 16,
#   'герман': 5,
#   'шекспир': 1,
#   'бабченко': 4,
#   'грицак': 1,
#   'вышинский': 5,
#   'медведев': 54,
#   'воробьев': 9,
#   'горьков': 1,
#   'шувалов': 1,
#   'аль-нахайяну': 1,
#   'аль-нахайян': 2,
#   'чемезов': 3,
#   'порошенко': 18,
#   'геращенко': 3,
#   'хантсман': 3,
#   'ушаков': 15,
#   'кириенко': 5,
#   'высокович': 1,
#   'шкаплер': 1,
#   'гасанов': 2,
#   'енилей': 1,
#   'пушман': 1,
#   'скрипаля': 15,
#   'юлия': 9,
#   'тун': 1,
#   'прилепа': 1,
#   'данила': 1,
#   'кэй': 1,
#   'теффт': 1,
#   'рейган': 4,
#   'ын': 17,
#   'киселев': 7,
#   'обама': 8,
#   'курец': 10,
#   'беллен': 1,
#   'ыну': 2,
#   'кузнецов': 2,
#   'жириновский': 3,
#   'смирнов': 9,
#   'калита': 1,
#   'лужков': 1,
#   'топилина': 2,
#   'асад': 15,
#   'ан-30': 1,
#   'петипа': 1,
#   'сен-санс': 1,
#   'бертман': 1,
#   'латам-кениг': 1,
#   'башмет': 1,
#   'хаматов': 1,
#   'макрон': 10,
#   'меньшиков': 1,
#   'чайковский': 1,
#   'мацуев': 2,
#   'ширалиев': 1,
#   'кудрин': 7,
#   'терентьев': 1,
#   'долженко': 1,
#   'чуприян': 1,
#   'абис': 1,
#   'ромашов': 1,
#   'шахов': 1,
#   'мамонтов': 2,
#   'генин': 1,
#   'степанов': 3,
#   'борисов': 4,
#   'мариничев': 2,
#   'жаров': 1,
#   'носков': 2,
#   'пивоварник': 2,
#   'милон': 1,
#   'дмитрий': 1,
#   'луценко': 3,
#   'клинцевич': 1,
#   'магомедов': 1,
#   'сыдорук': 1,
#   'хизриев': 1,
#   'гамидов': 1,
#   'талиб': 1,
#   'али': 1,
#   'мирходжа': 1,
#   'рахмон': 1,
#   'христос': 2,
#   'иисус': 1,
#   'мария': 2,
#   'солнце': 1,
#   'цзиньпин': 13,
#   'марьям': 1,
#   'васильев': 4,
#   'скрипаль': 5,
#   ')': 10,
#   'сергей': 3,
#   'курц': 5,
#   'яшин': 1,
#   'пель': 1,
#   'марадон': 1,
#   'миг-31': 1,
#   'телегин': 1,
#   'сергацков': 1,
#   'дубинчук': 1,
#   'явкина': 1,
#   'браверман': 2,
#   'свеженец': 1,
#   'ларионов': 1,
#   'федоров': 2,
#   'муткий': 3,
#   'караваев': 2,
#   'новак': 4,
#   'собчак': 3,
#   'шпак': 1,
#   'зимовец': 1,
#   'политик': 1,
#   'литвинец': 2,
#   'немировский': 1,
#   'парфенов': 1,
#   'антонюк': 1,
#   'никитин': 2,
#   'эйнштейн': 1,
#   'авак': 5,
#   'турчин': 3,
#   'аваков': 6,
#   'прилепин': 2,
#   'бастрыкин': 1,
#   'газзаев': 1,
#   'владимирович': 9,
#   'чудотворец': 1,
#   'черчесов': 6,
#   'георгий': 1,
#   'георгиевич': 1,
#   'колокольцев': 3,
#   'рашкин': 1,
#   'чайка': 1,
#   'бакланов': 1,
#   'грудинин': 1,
#   'верховский': 3,
#   'воскресенский': 3,
#   'рустамов': 1,
#   'жук': 1,
#   'слуцкий': 1,
#   'котрикадзе': 1,
#   'алексей': 1,
#   'артемьев': 2,
#   'козак': 5,
#   'сазан': 1,
#   'орешкин': 7,
#   'плутник': 1,
#   'джонсон': 2,
#   'мэй': 4,
#   'жиганов': 1,
#   'нестеров': 2,
#   'тюлин': 1,
#   'локотя': 1,
#   'городецкий': 1,
#   'локоть': 1,
#   'травниковый': 4,
#   'обухов': 1,
#   'шпорт': 1,
#   'вольф': 1,
#   'туск': 1,
#   'конт': 1,
#   'гага': 1,
#   'назарбаев': 1,
#   'матвиенко': 4,
#   'морозов': 1,
#   'матвеенко': 1,
#   'рябок': 2,
#   'ральник': 1,
#   'ральников': 1,
#   'реймер': 1,
#   'белоусов': 18,
#   '.': 2,
#   'титов': 3,
#   'патрушев': 2,
#   'брилев': 1,
#   'сенцов': 11,
#   'баттулга': 1,
#   'вовк': 2,
#   'меркель': 25,
#   'ельцин': 12,
#   'немцов': 4,
#   'золотов': 1,
#   'яковлев': 1,
#   'кричевский': 1,
#   'чубайс': 1,
#   'климкин': 3,
#   'помпео': 9,
#   'комаров': 2,
#   'рогозин': 3,
#   'кипшидзе': 1,
#   'волк': 1,
#   'севастьянов': 1,
#   'йонссон': 1,
#   'додон': 1,
#   'кьяртанссон': 1,
#   'кирилл': 8,
#   'громов': 2,
#   'вайно': 2,
#   'серышев': 1,
#   'сурков': 1,
#   'щетинин': 1,
#   'бурмистров': 2,
#   'рогачев': 2,
#   'клименко': 2,
#   'сущенко': 2,
#   'савченко': 2,
#   'кожин': 1,
#   'хаддада': 1,
#   'краснов': 1,
#   'анадол': 1,
#   'эрдоган': 9,
#   'силуановый': 9,
#   'макаров': 3,
#   'иной': 1,
#   'нам': 2,
#   'уильямс': 2,
#   'гарифуллин': 2,
#   'роналдо': 1,
#   'москаль': 3,
#   'головин': 1,
#   'шестун': 1,
#   'сауд': 1,
#   'собака': 1,
#   'харман': 1,
#   'блаттер': 2,
#   'инфантино': 4,
#   'пивненко': 1,
#   'подоляк': 1,
#   'кадыров': 12,
#   'денисов': 6,
#   'карпюк': 1,
#   'штыбликов': 1,
#   'москальков': 6,
#   'трутнев': 1,
#   'штрах': 2,
#   'тайсаев': 1,
#   'усс': 4,
#   'зубов': 1,
#   'левченко': 1,
#   'вятрович': 1,
#   'попов': 1,
#   'хмельницкий': 1,
#   'нойерт': 1,
#   'коронелли': 1,
#   'малаян': 1,
#   'феоктистов': 1,
#   'семенович': 1,
#   'собянин': 1,
#   'юриевич': 1,
#   'фатланд': 1,
#   'кикабидзе': 1,
#   'болтон': 30,
#   'лескин': 1,
#   'хорошавин': 1,
#   'горбачев': 3,
#   'карепкин': 1,
#   'лобкин': 1,
#   'икрам': 1,
#   'потомский': 1,
#   'селезнев': 1,
#   'клушин': 1,
#   'нектарий': 1,
#   'линкявичюс': 1,
#   'елена': 1,
#   'ремпель': 1,
#   'дашибалданов': 1,
#   'маркиз': 1,
#   'киммел': 3,
#   'борисович': 1,
#   'дьяченко': 3,
#   'юмашев': 3,
#   'бедрицкий': 2,
#   'телень': 1,
#   'ii': 1,
#   'абубакар': 1,
#   'иванов': 4,
#   'эдельгерий': 1,
#   'эдельгериев': 1,
#   'шойгу': 11,
#   'володин': 3,
#   'рос-лейтинен': 1,
#   'керим': 1,
#   'дерипаска': 2,
#   'мнучин': 1,
#   'вексельберг': 3,
#   'евтушенков': 1,
#   'лукашенко': 7,
#   'столтенберг': 5,
#   'цуркан': 1,
#   'петров': 1,
#   'ефимов': 1,
#   'арнольдович': 1,
#   'баракат': 1,
#   'бейль': 1,
#   'дитрих': 2,
#   'моисеев': 1,
#   'витко': 1,
#   'ткачев': 2,
#   'николаев': 2,
#   'щеголев': 1,
#   'белавенцев': 3,
#   'цукан': 1,
#   'матовник': 5,
#   'холманский': 2,
#   'матовников': 2,
#   'мишустин': 2,
#   'хувен': 2,
#   'кеннеди': 6,
#   'шелбить': 2,
#   'митчелла': 2,
#   'филатов': 1,
#   'этуш': 1,
#   'кобзон': 1,
#   'конюхов': 2,
#   'безруков': 1,
#   'савельев': 3,
#   'миронов': 1,
#   'тарпищев': 1,
#   'фетисов': 2,
#   'стратегии-2025': 1,
#   'роналда': 2,
#   'соуза': 1,
#   'пенс': 2,
#   'янукович': 2,
#   'манафорт': 1,
#   'ниинист': 10,
#   'яровой': 7,
#   'голенищев': 1,
#   'парубий': 4,
#   'захарченко': 5,
#   'лушник': 1,
#   'сноуден': 1,
#   'vi': 1,
#   'deyalta': 1,
#   'кобринский': 1,
#   'салман': 1,
#   'дмитриев': 1,
#   'клых': 1,
#   'соколов': 1,
#   'муженко': 4,
#   'конюх': 1,
#   'коньково': 1,
#   'петришенко': 2,
#   'ильенко': 1,
#   'i': 2,
#   'корнев': 2,
#   'матиос': 1,
#   'целуйко': 1,
#   'шишкин': 1,
#   'тарасенко': 1,
#   'миклушевский': 1,
#   'яров': 3,
#   'бастен': 1,
#   'скотт': 1,
#   'шмейхель': 1,
#   'форлан': 1,
#   'кампос': 1,
#   'фердинанд': 1,
#   'маттеус': 1,
#   'симонянин': 1,
#   'бобан': 1,
#   'соленов': 1,
#   'даххаев': 1,
#   'князев': 1,
#   'сысоев': 1,
#   'сарапулец': 1,
#   'потапов': 1,
#   'давыдов': 1,
#   'липилина': 1,
#   'мантурово': 2,
#   'нахайяном': 1,
#   'ротенберг': 2,
#   'турчинов': 1,
#   'коростелев': 1,
#   'байер': 1,
#   'трюдо': 1,
#   'черчес': 6,
#   'фаррадж': 1,
#   'бэннон': 1,
#   'бэнкса': 1,
#   'бэнкс': 1,
#   'яковенко': 1,
#   'бостром': 1,
#   'греф': 4,
#   'суфиановый': 1,
#   'науменко': 1,
#   'райффазенбанк': 1,
#   'бесков': 1,
#   'блохин': 1,
#   'дасаев': 1,
#   'петухов': 1,
#   'джон': 1,
#   'сергий': 1,
#   'михельсон': 1,
#   'тимченко': 1,
#   'алекперов': 1,
#   'шуфрич': 2,
#   'дубинин': 1,
#   'чейт': 1,
#   'буш': 3,
#   'ли': 2,
#   'царь-телефон': 1,
#   'велаять': 2,
#   'хаменея': 1,
#   'чиханчин': 1,
#   'лебедев': 1,
#   'улицкий': 1,
#   'познер': 1,
#   'гройсман': 2,
#   'кирша': 1,
#   'наев': 1,
#   'клегга': 1,
#   'лагер': 1,
#   'кэмерон': 1,
#   'мамонов': 1,
#   'бах': 1,
#   'козачек': 1,
#   'потемкин': 1,
#   'бадин': 1,
#   'нетыкшо': 1,
#   'малышев': 1,
#   'осадчук': 1,
#   'моргачев': 1,
#   'ковалев': 1,
#   'розенштейн': 1,
#   'антонов': 4,
#   'ершов': 1,
#   'лукашев': 1,
#   'ермаков': 1,
#   'боровков': 1,
#   'ондимб': 1,
#   'бозизя': 1,
#   'копперойнен': 1,
#   'маас': 1,
#   'акинфеев': 1,
#   'морган': 1,
#   'грабар-китарович': 4,
#   'таня': 1,
#   'джем': 1,
#   'роналдиньо': 1,
#   'забивак': 1,
#   'смит': 1,
#   'истрефи': 1,
#   'орбан': 2,
#   'хорват': 1,
#   'вид': 1,
#   'вукоевич': 1,
#   'ковальчук': 1,
#   'макгрегор': 1,
#   'магрегор': 1,
#   'дириоз': 1,
#   'мюллер': 1,
#   'клинтон': 9,
#   'белля': 1,
#   'мелания': 4,
#   'андреев': 1,
#   'кобзарь': 1,
#   'вишняков': 1,
#   'депардье': 1,
#   'олланд': 2,
#   'никоненко': 1,
#   'шамардин': 1,
#   'потанин': 3,
#   'мохов': 1,
#   'томенко': 2,
#   'никифоров': 2,
#   'семенюк': 1,
#   'датуна': 1,
#   'коллинза': 1,
#   'протестовать': 1,
#   'китарович': 1,
#   'бреннан': 2,
#   'келли': 1,
#   'витренко': 1,
#   'антело': 1,
#   'симоньян': 1,
#   'трампович': 1,
#   'шварценеггер': 2,
#   'сипиль': 1,
#   'уоллес': 3,
#   'политковский': 1,
#   'кинг': 1,
#   'буш-старший': 1,
#   'ной': 1,
#   'сенький': 1,
#   '2.0': 2,
#   'сэм': 1,
#   'набиуллин': 4,
#   'розенстайн': 1,
#   'мураховский': 2,
#   'ломидзе': 1,
#   'леонок': 1,
#   'леонтиевич': 1,
#   'тиллерсон': 2,
#   'калын': 1,
#   'гюлен': 1,
#   'дронов': 1,
#   'райан': 1,
#   'гросс': 1,
#   'шахин': 1,
#   'баррасо': 1,
#   'джексон': 2,
#   'касатонов': 1,
#   'костин': 1,
#   'перцев': 1,
#   'бурсон': 1,
#   'нестечук': 1,
#   'трунин': 1,
#   'сандерс': 7,
#   'макфол': 1,
#   'браудер': 1,
#   'поладить': 1,
#   'коутс': 2,
#   'ил-96': 2,
#   'маркис': 1,
#   'тук': 1,
#   'минниханов': 4,
#   'овечкин': 2,
#   'шипман': 1,
#   'офелейн': 1,
#   'накасон': 2,
#   'олсен': 1,
#   'марран': 1,
#   'ильвес': 1,
#   'юхтег': 1,
#   'аристов': 1,
#   'выползов': 1,
#   'ильтяков': 1,
#   'аль-машат': 3,
#   'хади': 3,
#   'доронкин': 1,
#   'журавко': 1,
#   'хейль': 1,
#   'силуанов': 3,
#   'кожемякий': 2,
#   'сивко': 2,
#   'хайтен': 2,
#   'гордеев': 2,
#   'венедиктов': 1,
#   'алиев': 2,
#   'пашинян': 2,
#   'пашинянин': 2,
#   'модь': 1,
#   'темер': 1,
#   'рамафоса': 1,
#   'коллинс': 1,
#   'юнкер': 1,
#   'шина': 1,
#   'кейтлан': 1,
#   'райс': 2,
#   'бутин': 1,
#   'анохин': 1,
#   'омелян': 1,
#   'нельсон': 1,
#   'кушнер': 1,
#   'киссинджер': 1,
#   'си': 1,
#   'конда': 1,
#   'тревитик': 1,
#   'кодевилл': 1,
#   'дзюба': 2,
#   'рон': 1,
#   'игнашевич': 1,
#   'акинфей': 1,
#   'модрич': 1,
#   'батов': 1,
#   'волков': 1,
#   'тасун': 1,
#   'белых': 1,
#   'чернышов': 1,
#   'мухачев': 1,
#   'улюкаев': 1,
#   'криворотов': 1,
#   'картапол': 1,
#   'каньшин': 1,
#   'эйсмонт': 1,
#   'чжэньмин': 1,
#   'дворкович': 1,
#   'левов': 1,
#   'репик': 1,
#   'шохин': 5,
#   'катырин': 1,
#   'рейльян': 1,
#   'астахов': 1,
#   'копин': 2,
#   'юров': 1,
#   'кобылкин': 1,
#   'корнелюк': 1,
#   'александров': 1,
#   'волошин': 1,
#   'ерофеев': 1,
#   'бауэрс': 1,
#   'кристенсен': 1,
#   'сергеев': 1,
#   'камин': 1,
#   'михальченко': 1,
#   'лапыгин': 1,
#   'кармановский': 2,
#   'крид': 3,
#   'витас': 4,
#   'петросян': 5,
#   'жорин': 5,
#   'птаха': 4,
#   'степаненко': 5,
#   'забралов': 5,
#   'джигурда': 2,
#   'сечин': 3,
#   'анисин': 2,
#   'тимати': 3,
#   'мордашов': 4,
#   'орлов': 2,
#   'данфорд': 2,
#   'герасимов': 2,
#   'сигать': 6,
#   'рэй': 1,
#   'нильсен': 1,
#   'баталин': 1,
#   'слепцов': 1,
#   'сигалу': 1,
#   'якушев': 3,
#   'моор': 1,
#   'пхаладзе': 1,
#   'маргвелашвили': 1,
#   'хулордав': 1,
#   'вольский': 1,
#   'кобяков': 2,
#   'гусев': 2,
#   'динза': 1,
#   'перчян': 1,
#   'саакашвили': 4,
#   'иванишвили': 1,
#   'менендес': 1,
#   'грэм': 1,
#   'магнитский': 1,
#   'кардин': 1,
#   'гарднер': 1,
#   'шаманов': 2,
#   'каныгин': 1,
#   'саркози': 1,
#   'слепнев': 1,
#   'росся': 1,
#   'маккарти': 1,
#   'симонс': 1,
#   'герреро': 1,
#   'науэрта': 1,
#   'лисиный': 6,
#   'мин\u200bтруд': 1,
#   'ляйена': 1,
#   'абдрахманов': 1,
#   'никсон': 1,
#   'стайн': 1,
#   'форд': 1,
#   'рэмбо': 1,
#   'тимошенко': 1,
#   'юля': 1,
#   'рашник': 1,
#   'абрамович': 1,
#   'романенко': 1,
#   'ющенко': 1,
#   'маккейн': 2,
#   'пипия': 1,
#   'руцкой': 1,
#   'шевченко': 1,
#   'бабин': 1,
#   'жебривский': 1,
#   'толкин': 1,
#   'гэндальф': 1,
#   'конан': 1,
#   'мартин': 1,
#   'бальдерсон': 1,
#   'касич': 1,
#   'кольберт': 1,
#   'серьга': 1,
#   'простоквашино': 1,
#   'чебурашка': 1,
#   'ирина': 1,
#   'успенский': 1,
#   'ким': 1,
#   'вы': 1,
#   'ленин': 1,
#   'черышев': 1,
#   'топилин': 1,
#   'хадий': 1,
#   'джамалуддин': 1,
#   'николай': 1,
#   'шамиль': 1,
#   'стариков': 1,
#   'измайлов': 1,
#   'маркович': 1,
#   'поклонской': 2,
#   'соловьев': 1,
#   'кнайсль': 18,
#   'сидоров': 1,
#   'валехидис': 1,
#   'гречин': 1,
#   'саттар': 1,
#   'агеев': 1,
#   'камал': 1,
#   'шаталов': 1,
#   'седиков': 1,
#   'доронин': 1,
#   'высоцкий': 1,
#   'кашуб': 4,
#   'калинин': 1,
#   'владимир': 1,
#   'михеев': 1,
#   'эдгард': 1,
#   'машков': 1,
#   'запашный': 1,
#   'одновол': 1,
#   'раймон': 2,
#   'берра': 1,
#   'майлингер': 11,
#   'баркиндо': 1,
#   'кунасек': 2,
#   'кухарев': 1,
#   'ляшенко': 1,
#   'румас': 1,
#   'марч': 1,
#   'бруклин': 1,
#   'панин': 1,
#   'шредер': 2,
#   'нурипур': 1,
#   'ламбсдорф': 1,
#   'шмид': 1,
#   'богданов': 2,
#   'зимин': 1,
#   'хоркина': 1,
#   'святослав': 1,
#   'хант': 1,
#   'кравченко': 1,
#   'сафонов': 1,
#   'гришин': 1,
#   'кустурица': 1,
#   'буртина': 1,
#   'мантуров': 3,
#   'мониава': 1,
#   'коннов': 1,
#   'скворцов': 1,
#   'петрушенко': 1,
#   'хофер': 1,
#   'лунгеска': 1,
#   'воеводин': 1,
#   'филимонов': 1,
#   'бубен': 1,
#   'викторович': 1,
#   'бабич': 1,
#   'суриков': 1,
#   'томос': 1,
#   'рейбанда': 1,
#   'гайдук': 1,
#   'бахтадзе': 1,
#   'дьяконов': 1,
#   'кураев': 1,
#   'паньков': 1,
#   'куренной': 1,
#   'капчук': 1,
#   'черненко': 2,
#   'александр': 1,
#   'цивилев': 1,
#   'бортников': 9,
#   'кара-оол': 5,
#   'лимонов': 1,
#   'дудь': 1,
#   'xiv': 1,
#   'гриллс': 1,
#   'белозеров': 2,
#   'калинкин': 1,
#   'варченко': 1,
#   'корючин': 1,
#   'ванеев': 1,
#   'ильинов': 1,
#   'бегун': 1,
#   'коршунов': 1,
#   'бойко': 1,
#   'сорокин': 1,
#   'вдовин': 1,
#   'акимов': 1,
#   'умаров': 1,
#   'ахматович': 2,
#   'байден': 1,
#   'кара-мурза': 1,
#   'файнголд': 1,
#   'коэн': 1,
#   'кара-мурза-младший': 1,
#   'битти': 1,
#   'гусаров': 1,
#   'полубояринов': 1,
#   'памфилов': 1,
#   'каримов': 2,
#   'чуканов': 1,
#   'миллер': 2,
#   'шонесси': 1,
#   'мэттис': 1,
#   'ковтун': 1,
#   'вовка': 1,
#   'тимофеев': 2},
#  'олл': {},
#  'голиков': {'путин': 7,
#   'медведев': 6,
#   'топилина': 4,
#   'роструд': 1,
#   'козак': 1,
#   'шувалов': 1,
#   'володин': 1,
#   'дубина': 1,
#   'силуановый': 2,
#   'кудрин': 1},
#  'лок': {'блок': 3,
#   'путин': 2,
#   'рютта': 1,
#   'порошенко': 3,
#   'климкин': 1,
#   'трамп': 1},
#  'блок': {'лок': 3,
#   'путин': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
# ...
#   'жуковский': 1,
#   'симеонов-пищик': 1,
#   'антуан': 1,
#   'сэм': 1,
#   'караулов': 1,
#   'хлынов': 1,
#   'кощей': 1},
#  'степашин': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1},
#  'мороз': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1,
#   'лонгортов': 1,
#   'белов': 1,
#   'морозов': 1,
#   'бегемотов': 1,
#   'воробьев': 1,
#   'никита': 1,
#   'даниил': 1,
#   'татьяна': 1},
#  'данилкин': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1},
#  'отрошенко': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1},
#  'григорьев': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1,
#   'аммосов': 1},
#  'добров': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1},
#  'григорьян': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1},
#  'смех': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1},
#  'окуджава': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1,
#   'коржавин': 1,
#   'винокуров': 1,
#   'долина': 1,
#   'мандель': 1,
#   'чуковский': 1,
#   'солженицын': 1,
#   'евтушенко': 1,
#   'шенталинсикий': 1,
#   'шенталинский': 1},
#  'пушкин': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 2,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1,
#   'пенни': 1,
#   'джеймс': 1,
#   'ивар': 1,
#   'элла': 1,
#   'маунтбаттен': 1,
#   'i': 1,
#   'аликс': 1,
#   'ii': 1,
#   'луль': 1,
#   'торбь': 1,
#   'койлом': 1,
#   'гринькива': 1,
#   'михайлов': 1,
#   'булгаков': 1,
#   'пастернак': 1,
#   'достоевский': 1,
#   'володин': 1,
#   'филиппов': 1,
#   'налич': 1,
#   'германн': 1,
#   'легчак': 1,
#   'гончаров': 1,
#   'кормухин': 1,
#   'воробьев': 1,
#   'серов': 1,
#   'печенегин': 1,
#   'майдан': 1,
#   'юденич': 1,
#   'губерний': 1,
#   'огурцов': 1,
#   'маликов': 1,
#   'легков': 1,
#   'кончаловский': 1,
#   'монсон': 1,
#   'камаева': 1},
#  'репак': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1},
#  'майя': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1,
#   'аллах': 1,
#   'мохаммед': 1,
#   ')': 1},
#  'сеславинский': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1},
#  'блик': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1},
#  'банкир': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1},
#  'швыдка': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'богатырев': 1,
#   'лист': 1,
#   'теркин': 1},
#  'богатырев': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'лист': 1,
#   'теркин': 1},
#  'лист': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'теркин': 1},
#  'теркин': {'блок': 1,
#   'рудин': 1,
#   'ант': 1,
#   'северянин': 1,
#   'киселев': 1,
#   'садковый': 1,
#   'бальмонт': 1,
#   'самойлов': 1,
#   'маяковский': 1,
#   'толстой': 1,
#   'степашин': 1,
#   'мороз': 1,
#   'данилкин': 1,
#   'отрошенко': 1,
#   'григорьев': 1,
#   'добров': 1,
#   'григорьян': 1,
#   'смех': 1,
#   'родионов': 1,
#   'окуджава': 1,
#   'пушкин': 1,
#   'репак': 1,
#   'майя': 1,
#   'сеславинский': 1,
#   'блик': 1,
#   'банкир': 1,
#   'швыдка': 1,
#   'богатырев': 1,
#   'лист': 1},
#  'канатов': {},
#  'кахрамонович': {'егорец': 1,
#   'жумабаевич': 1,
#   'гафорович': 1,
#   'абдимаматович': 1,
#   'саматович': 1,
#   'кимсанович': 1},
#  'жумабаевич': {'кахрамонович': 1,
#   'егорец': 1,
#   'гафорович': 1,
#   'абдимаматович': 1,
#   'саматович': 1,
#   'кимсанович': 1},
#  'гафорович': {'кахрамонович': 1,
#   'егорец': 1,
#   'жумабаевич': 1,
#   'абдимаматович': 1,
#   'саматович': 1,
#   'кимсанович': 1},
#  'абдимаматович': {'кахрамонович': 1,
#   'егорец': 1,
#   'жумабаевич': 1,
#   'гафорович': 1,
#   'саматович': 1,
#   'кимсанович': 1},
#  'саматович': {'кахрамонович': 1,
#   'егорец': 1,
#   'жумабаевич': 1,
#   'гафорович': 1,
#   'абдимаматович': 1,
#   'кимсанович': 1},
#  'кимсанович': {'кахрамонович': 1,
#   'егорец': 1,
#   'жумабаевич': 1,
#   'гафорович': 1,
#   'абдимаматович': 1,
#   'саматович': 1},
#  'погб': {'месси': 3,
#   'мюллер': 2,
#   'мостик': 1,
#   'роналда': 3,
#   'брюйн': 2,
#   'кейн': 2,
#   'акинфей': 1,
#   'неймар': 4,
#   'родригес': 1,
#   'агуэро': 1,
#   'мбапп': 2,
#   'мария': 1,
#   'силва': 1,
#   'суарес': 1,
#   'единак': 2,
#   'гризманн': 3,
#   'поульсен': 1,
#   'куэв': 1,
#   'неймара': 1,
#   'акинфеев': 1,
#   'черчесов': 1,
#   'перишич': 1,
#   'манджукич': 1,
#   'моуринья': 4,
#   'магуайра': 1,
#   'дайк': 1,
#   'перейра': 1,
#   'поль': 1,
#   'скотт': 1,
#   'фред': 1,
#   'мактоминь': 1,
#   'мактоминея': 1,
#   'коутинья': 1},
#  'мостик': {'месси': 1,
#   'мюллер': 1,
#   'погб': 1,
#   'роналда': 1,
#   'брюйн': 1,
#   'кейн': 1,
#   'акинфей': 1,
#   'неймар': 1,
#   'ротенберг': 1},
#  'брюйн': {'месси': 2,
#   'мюллер': 2,
#   'погб': 2,
#   'мостик': 1,
#   'роналда': 3,
#   'кейн': 3,
#   'акинфей': 1,
#   'неймар': 3,
#   'неймара': 1,
#   'акинфеев': 1,
#   'черчесов': 2,
#   'аугусто': 2,
#   'фернандинья': 2,
#   'варан': 1,
#   'гризманн': 2,
#   'меркадо': 1,
#   'метшин': 1,
#   'мессия': 1,
#   'агуэро': 1,
#   'мбапп': 1,
#   'кавани': 1,
#   'пеп': 1,
#   'модрич': 2,
#   'мария': 1,
#   'павар': 1,
#   'азар': 1,
#   'шмейхель': 1,
#   'гранквист': 1,
#   'триппьер': 1,
#   'кутеп': 1,
#   'марсело': 1,
#   'фернандес': 1,
#   'мина': 1},
#  'басурин': {'харахшех': 1, 'павлов': 1, 'воха': 1, 'моторола': 1, 'жог': 1},
#  'харахшех': {'басурин': 1},
#  'семченка': {'семченок': 1},
#  'семченок': {'семченка': 1},
#  'хэнсен': {')': 1, 'хот-дог': 1, 'пипп': 1, 'пиппа': 1, 'кэсся': 1},
#  'хот-дог': {'хэнсен': 1, ')': 1, 'пипп': 1, 'пиппа': 1, 'кэсся': 1},
#  'пипп': {'хэнсен': 1,
#   ')': 1,
#   'хот-дог': 1,
#   'пиппа': 1,
#   'кэсся': 1,
#   'марклый': 2,
#   'maven': 1,
#   'гарри': 2,
#   'миддлтон': 2,
#   'лонгмор': 1,
#   'анжелина': 1,
#   'меган': 1,
#   'джоля': 1,
#   'сассекский': 1},
#  'пиппа': {'хэнсен': 1, ')': 1, 'хот-дог': 1, 'пипп': 1, 'кэсся': 1},
#  'кэсся': {'хэнсен': 1, ')': 1, 'хот-дог': 1, 'пипп': 1, 'пиппа': 1},
#  'шаролов': {},
#  'каруан': {'карлсен': 1, 'карякин': 1, 'мамедьяров': 1},
#  'карлсен': {'каруан': 1, 'карякин': 1, 'мамедьяров': 1},
#  'карякин': {'каруан': 1, 'карлсен': 1, 'мамедьяров': 1},
#  'мамедьяров': {'каруан': 1, 'карлсен': 1, 'карякин': 1},
#  'леонид': {'кантер': 1,
#   'гай': 1,
#   'кантереть': 1,
#   'кантера': 1,
#   'лищинский': 1,
#   'манаширов': 1,
#   'белых': 1,
#   'рома': 1,
#   'дрыманов': 1,
#   'гайзер': 1,
#   'юриевич': 1,
#   'магомедов': 1,
#   'маркелов': 1,
#   'шестун': 1},
#  'гай': {'леонид': 1,
#   'кантер': 1,
#   'кантереть': 1,
#   'кантера': 1,
#   'лищинский': 1},
#  'кантера': {'леонид': 1,
#   'кантер': 1,
#   'гай': 1,
#   'кантереть': 1,
#   'лищинский': 1},
#  'лищинский': {'леонид': 1,
#   'кантер': 1,
#   'гай': 1,
#   'кантереть': 1,
#   'кантера': 1},
#  'хизрий': {'хизриев': 1},
#  'бородать': {},
#  'вонг': {'пеннер': 1, ')': 1},
#  'пеннер': {'вонг': 1, ')': 1},
#  'закондырин': {},
#  'петрашкен': {')': 1},
#  'ши': {')': 3,
#   'ся': 1,
#   'цинь': 1,
#   'поло': 1,
#   'шихуанди': 1,
#   'фуцюня': 1,
#   'допросить': 1},
#  'тракало': {'кантереть': 1, 'кантер': 1, 'энберг': 1, 'жалимас': 1},
#  'макгрегор': {'месси': 1,
#   'роналда': 2,
#   'мэйуэзер': 5,
#   'нурмагомедов': 27,
#   'хант': 1,
#   'хабиб': 6,
#   'нурмагомед': 24,
#   'уайт': 7,
#   'олейник': 1,
#   'конор': 3,
#   'абдулманап': 3,
#   'конора': 6,
#   'макрегор': 2,
#   'аскелович': 1,
#   'альварес': 1,
#   'магрегор': 1,
#   'путин': 1,
#   'лобов': 3,
#   'борг': 1,
#   'кьеза': 1,
#   'диас': 1,
#   'яквинта': 2,
#   'нурмагомедов-старший': 2,
#   'абубакар': 1,
#   'ли': 1,
#   'фергюсон': 1,
#   'трамп': 2,
#   'льюис': 1,
#   'куницкий': 1,
#   'волков': 1,
#   'лансберг': 1,
#   'махачев': 1,
#   'вайнах': 1,
#   'бадургов': 2,
#   'бадург': 2,
#   'тухугов': 2,
#   'зуб': 1,
#   'мендес': 1,
#   'флойд-старший': 2,
#   'мэйуэзер-младший': 1,
#   'флойда': 1,
#   'роджер': 2,
#   'ирландец': 1,
#   'мэйуэзера-младший': 1,
#   'новоа': 1,
#   'эстрада': 1,
#   'менайотин': 1,
#   'тударуан': 1,
#   'абдель-азиз': 1},
#  'мэйуэзер': {'макгрегор': 5,
#   'месси': 1,
#   'роналда': 1,
#   'фукусима': 1,
#   'cent': 1,
#   'нурмагомедов': 4,
#   'хабиб': 1,
#   'конора': 1,
#   'флойд-старший': 2,
#   'мэйуэзер-младший': 1,
#   'флойда': 1,
#   'роджер': 2,
#   'ирландец': 1,
#   'мэйуэзера-младший': 1,
#   'новоа': 1,
#   'эстрада': 1,
#   'менайотин': 1,
#   'тударуан': 1,
#   'макрегор': 1},
#  'девараджан': {'трамп': 1},
#  'варламов': {'собянин': 3,
#   'яшин': 3,
#   'красовский': 3,
#   'гудков': 3,
#   'стерлигов': 3,
#   'джигурд': 1,
#   'карачаушев': 1},
#  'гудков': {'собянин': 7,
#   'яшин': 7,
#   'варламов': 3,
#   'красовский': 8,
#   'стерлигов': 7,
#   'джигурд': 5,
#   'реут': 3,
#   'троицкий': 2,
#   'паук': 1,
#   'балакин': 1,
#   'кумин': 1,
#   'джигурду': 1,
#   'дегтярев': 1,
#   'свиридов': 1,
#   'митрохин': 1,
#   'терешина': 1,
#   'милявский': 1,
#   'бузов': 1,
#   'королева': 1,
#   'рудковский': 1,
#   'билан': 1,
#   'фэйс': 1,
#   'лепс': 1,
#   'сардар': 1,
#   'миногаров': 1,
#   'киркоров': 1,
#   'басков': 1,
#   'гнойный': 1,
#   'запашный': 1,
#   'тимати': 1,
#   'ивлеева': 1},
#  'стерлигов': {'собянин': 7,
#   'яшин': 7,
#   'варламов': 3,
#   'красовский': 7,
#   'гудков': 7,
#   'байдак': 1,
#   'восканян': 1,
#   'джигурд': 5,
#   'реут': 3,
#   'троицкий': 2,
#   'паук': 1,
#   'балакин': 1,
#   'кумин': 1,
#   'джигурду': 1,
#   'дегтярев': 1,
#   'свиридов': 1,
#   'митрохин': 1},
#  'ермолаев': {'солдатенков': 1,
#   'торбахов': 1,
#   'медведев': 1,
#   'иванов': 1,
#   'канаев': 1,
#   'ребриков': 1},
#  'солдатенков': {'ермолаев': 1,
#   'семин': 1,
#   'риди': 1,
#   'гринчук': 1,
#   'ступино': 1},
#  ...}

# %% [markdown]
# Возьмем не все действующие лица, а только самых упоминаемых героев, которые упоминались хотя бы в 21 статье.

# %%
# Возьмем тех, кто упоминается более 20 раз.
names2 = [n + "_" + str(names[n]) for n in names.keys() if names[n] > 20]
names2
# Out:
# [')_951',
#  'воробьев_153',
#  'васильев_21',
#  'иванов_46',
#  'порошенко_157',
#  'лавров_48',
#  'ына_59',
#  'трамп_674',
#  'путин_815',
#  'герман_25',
#  'бабченко_28',
#  'песков_142',
#  'черчесов_83',
#  'джонсон_43',
#  'салах_32',
#  'молодой_21',
#  'роналда_115',
#  'неймар_42',
#  'кудрявцев_85',
#  'смит_28',
#  'головин_59',
#  '(_27',
#  'марков_23',
#  'ын_87',
#  'кардашьян_58',
#  'ким_21',
#  'сенцов_44',
#  'медведев_175',
#  'орешкин_23',
#  'дерипаска_30',
#  'луценко_21',
#  'юнкер_21',
#  'лукашенко_42',
#  'петросян_25',
#  'овечкин_26',
#  'уэст_35',
#  'эрдоган_61',
#  'мэй_52',
#  'климкин_23',
#  'силуановый_41',
#  'макрон_43',
#  'уильямс_53',
#  'вагнер_26',
#  'вайнштейн_21',
#  'столтенберг_21',
#  'кузнецов_23',
#  'асад_63',
#  'месси_61',
#  'скрипаля_61',
#  'юлия_66',
#  'черышев_33',
#  'смолов_41',
#  'дзюба_63',
#  'акинфей_35',
#  'игнашевич_29',
#  'фернандес_24',
#  'маск_36',
#  'обама_36',
#  'ii_52',
#  'меркель_66',
#  'мартин_23',
#  'дженнер_26',
#  'помпео_43',
#  'коэн_22',
#  'мбапп_24',
#  'кейн_25',
#  'скрипаль_55',
#  'захарченко_34',
#  'топилина_27',
#  'кадыров_68',
#  'клинтон_31',
#  'лебедев_21',
#  'борисов_27',
#  '._42',
#  'собянин_33',
#  'володин_21',
#  'сандерс_28',
#  'цзиньпин_25',
#  'черчес_50',
#  'шойгу_24',
#  'макгрегор_36',
#  'марклый_66',
#  'гарри_66',
#  'кобзон_22',
#  'рогозин_30',
#  'кирилл_32',
#  'миддлтон_24',
#  'гройсман_24',
#  'белоусов_21',
#  'ельцин_24',
#  'захаров_53',
#  'болтон_46',
#  'нурмагомедов_27',
#  'нурмагомед_25',
#  'маска_35',
#  'макаров_49',
#  'москальков_26',
#  'модрич_27',
#  'акинфеев_34',
#  'стерджесс_31',
#  'роули_28',
#  'вид_28',
#  'гюлен_23',
#  'омелян_31',
#  'бутин_31',
#  'брансон_21',
#  'расторгуев_25',
#  'радченко_25']

# %% [markdown]
# Связи будем отслеживать только между самыми заметными героями новостей. Для этого отсеем всех, кто не входит в список наиболее часто встречающихся.

# %%
pers2 = {n:{n2:connections[n][n2] for n2 in connections[n].keys() if names[n2] > 20 and n2 != ')'}
            for n in connections.keys() if names[n]>20 and n!=')'}
pers2
# Out:
# {'воробьев': {'путин': 9,
#   'марков': 7,
#   'кузнецов': 1,
#   'макрон': 1,
#   'собянин': 12,
#   'медведев': 2,
#   'шойгу': 2,
#   'володин': 1,
#   'захаров': 6,
#   'борисов': 1,
#   'лебедев': 1,
#   'кирилл': 1,
#   'акинфеев': 1},
#  'васильев': {'иванов': 1, 'путин': 4, 'головин': 3, 'мбапп': 1},
#  'иванов': {'васильев': 1,
#   'герман': 1,
#   'бабченко': 1,
#   'луценко': 1,
#   'медведев': 1,
#   'кадыров': 1,
#   'путин': 4,
#   'макаров': 1,
#   'сенцов': 2,
#   'акинфеев': 1,
#   'акинфей': 1,
#   'трамп': 1,
#   'столтенберг': 1,
#   'шойгу': 2,
#   'петросян': 1,
#   'кудрявцев': 1},
#  'порошенко': {'путин': 18,
#   'захарченко': 1,
#   'бабченко': 1,
#   'столтенберг': 5,
#   'сенцов': 4,
#   '.': 1,
#   'климкин': 6,
#   'москальков': 2,
#   'гройсман': 5,
#   'захаров': 1,
#   'трамп': 9,
#   'вид': 2,
#   'макрон': 2,
#   'юнкер': 2,
#   'уэст': 1,
#   'гюлен': 1,
#   'эрдоган': 1,
#   'омелян': 3,
#   'луценко': 2,
#   'болтон': 2,
#   'медведев': 1,
#   'меркель': 1},
#  'лавров': {'ына': 13,
#   'трамп': 17,
#   'путин': 21,
#   'ын': 13,
#   'обама': 1,
#   'песков': 2,
#   'цзиньпин': 3,
#   'джонсон': 2,
#   'мэй': 1,
#   'захаров': 5,
#   'болтон': 3,
#   'неймар': 1,
#   'шойгу': 1,
#   'скрипаля': 1,
#   'юлия': 1,
#   'ким': 1,
#   'меркель': 1,
#   'помпео': 2,
#   'асад': 2},
#  'ына': {'лавров': 13,
#   'трамп': 52,
#   'путин': 16,
#   'ын': 45,
#   'асад': 1,
#   'обама': 1,
#   'песков': 2,
#   'сандерс': 3,
#   'ким': 5,
#   'болтон': 1,
#   'помпео': 6,
#   'климкин': 1,
#   'ельцин': 1,
#   'цзиньпин': 3,
#   'марклый': 1,
#   'джонсон': 1,
#   'гарри': 1,
#   'миддлтон': 1},
#  'трамп': {'лавров': 17,
#   'ына': 52,
#   'путин': 209,
#   'ын': 72,
#   'кардашьян': 4,
#   'джонсон': 11,
#   'ким': 13,
#   'юнкер': 14,
#   'уэст': 3,
#   'мэй': 15,
#   'асад': 6,
#   'обама': 26,
#   'песков': 31,
#   'клинтон': 23,
#   'сандерс': 23,
#   'цзиньпин': 8,
#   'макрон': 11,
#   'помпео': 29,
#   'овечкин': 3,
#   'меркель': 22,
#   'болтон': 35,
#   'климкин': 3,
#   'ельцин': 1,
#   'марклый': 1,
#   'гарри': 1,
#   'орешкин': 3,
#   'кудрявцев': 1,
#   'эрдоган': 14,
#   'рогозин': 1,
#   'столтенберг': 5,
#   'вайнштейн': 2,
#   'роналда': 1,
#   'дерипаска': 3,
#   'черчесов': 1,
#   'коэн': 11,
#   'ii': 10,
#   'порошенко': 9,
#   'иванов': 1,
#   'герман': 2,
#   'скрипаля': 5,
#   'юлия': 3,
#   '(': 1,
#   'гройсман': 1,
#   'скрипаль': 2,
#   'бутин': 4,
#   'брансон': 16,
#   'гюлен': 14,
#   'медведев': 3,
#   'макгрегор': 2,
#   'нурмагомедов': 2,
#   'нурмагомед': 2,
#   'захаров': 2,
#   'москальков': 1,
#   'кадыров': 1},
#  'путин': {'лавров': 21,
#   'ына': 16,
#   'трамп': 209,
#   'песков': 95,
#   'кудрявцев': 16,
#   'герман': 5,
#   'бабченко': 4,
#   'медведев': 54,
#   'воробьев': 9,
#   'порошенко': 18,
#   'скрипаля': 15,
#   'юлия': 9,
#   'ын': 17,
#   'обама': 8,
#   'кузнецов': 2,
#   'топилина': 2,
#   'асад': 15,
#   'макрон': 10,
#   'борисов': 4,
#   'луценко': 3,
#   'цзиньпин': 13,
#   'васильев': 4,
#   'скрипаль': 5,
#   'черчесов': 6,
#   'орешкин': 7,
#   'джонсон': 2,
#   'мэй': 4,
#   'белоусов': 18,
#   '.': 2,
#   'сенцов': 11,
#   'меркель': 25,
#   'ельцин': 12,
#   'климкин': 3,
#   'помпео': 9,
#   'рогозин': 3,
#   'кирилл': 8,
#   'эрдоган': 9,
#   'силуановый': 9,
#   'макаров': 3,
#   'уильямс': 2,
#   'головин': 1,
#   'кадыров': 12,
#   'москальков': 6,
#   'собянин': 1,
#   'болтон': 30,
#   'ii': 1,
#   'иванов': 4,
#   'шойгу': 11,
#   'володин': 3,
#   'дерипаска': 2,
#   'лукашенко': 7,
#   'столтенберг': 5,
#   'кобзон': 1,
#   'роналда': 2,
#   'захарченко': 5,
#   'черчес': 6,
#   'лебедев': 1,
#   'гройсман': 2,
#   'акинфеев': 1,
#   'смит': 1,
#   'вид': 1,
#   'макгрегор': 1,
#   'клинтон': 9,
#   'гюлен': 1,
#   'сандерс': 7,
#   'овечкин': 2,
#   'юнкер': 1,
#   'бутин': 1,
#   'омелян': 1,
#   'дзюба': 2,
#   'игнашевич': 1,
#   'акинфей': 1,
#   'модрич': 1,
#   'петросян': 5,
#   'мартин': 1,
#   'ким': 1,
#   'черышев': 1,
#   'коэн': 1},
#  'герман': {'бабченко': 22,
#   'песков': 3,
#   'путин': 5,
#   'луценко': 4,
#   'иванов': 1,
#   'скрипаля': 1,
#   'скрипаль': 1,
#   'столтенберг': 1,
#   '.': 3,
#   'сенцов': 1,
#   'трамп': 2},
#  'бабченко': {'герман': 22,
#   'песков': 3,
#   'путин': 4,
#   'луценко': 5,
#   'климкин': 1,
#   'иванов': 1,
#   'порошенко': 1,
#   'скрипаля': 1,
#   'скрипаль': 1,
#   'столтенберг': 1,
#   '.': 3,
#   'сенцов': 1},
#  'песков': {'герман': 3,
#   'бабченко': 3,
#   'путин': 95,
#   'лавров': 2,
#   'ын': 2,
#   'ына': 2,
#   'трамп': 31,
#   'меркель': 12,
#   'цзиньпин': 2,
#   'белоусов': 4,
#   'медведев': 10,
#   'сандерс': 2,
#   'климкин': 2,
#   'макрон': 4,
#   'месси': 1,
#   'кадыров': 7,
#   'кобзон': 1,
#   'обама': 1,
#   'салах': 1,
#   'сенцов': 5,
#   'болтон': 9,
#   'ельцин': 4,
#   'помпео': 3,
#   'столтенберг': 2,
#   'орешкин': 1,
#   'черчесов': 1,
#   'акинфей': 1,
#   'асад': 2,
#   'юлия': 2,
#   'скрипаль': 2,
#   'черчес': 1,
#   'скрипаля': 4,
#   'мэй': 2,
#   'джонсон': 1,
#   'эрдоган': 1,
#   'брансон': 1,
#   'кудрявцев': 1,
#   'собянин': 2,
#   'шойгу': 8,
#   'клинтон': 1},
#  'черчесов': {'черышев': 6,
#   'смолов': 6,
#   'дзюба': 11,
#   'акинфей': 4,
#   'головин': 7,
#   'игнашевич': 6,
#   'фернандес': 6,
#   'смит': 1,
#   'черчес': 22,
#   'путин': 6,
#   'месси': 2,
#   'салах': 3,
#   'неймар': 2,
#   'кадыров': 2,
#   'кирилл': 1,
#   'уильямс': 1,
#   'акинфеев': 5,
#   'роналда': 1,
#   'кейн': 2,
#   'трамп': 1,
#   'песков': 1,
#   'медведев': 1,
#   'овечкин': 1,
#   'модрич': 2},
#  'джонсон': {'кардашьян': 4,
#   'ын': 1,
#   'ким': 1,
#   'трамп': 11,
#   'скрипаля': 4,
#   'юлия': 2,
#   'мэй': 19,
#   'путин': 2,
#   'медведев': 1,
#   'скрипаль': 1,
#   'лавров': 2,
#   'захаров': 1,
#   'марклый': 1,
#   'гарри': 1,
#   'ына': 1,
#   'миддлтон': 1,
#   'макрон': 1,
#   'песков': 1,
#   'ii': 2,
#   'меркель': 1,
#   'кадыров': 2,
#   'смит': 1,
#   'дженнер': 1},
#  'салах': {'месси': 6,
#   'роналда': 4,
#   'мбапп': 2,
#   'кейн': 2,
#   'головин': 2,
#   'черчесов': 3,
#   'игнашевич': 2,
#   'неймар': 1,
#   'кадыров': 12,
#   'кобзон': 1,
#   'обама': 1,
#   'песков': 1,
#   'акинфеев': 5,
#   'дзюба': 4,
#   'черышев': 5,
#   'фернандес': 1,
#   'акинфей': 1,
#   'модрич': 2,
#   'черчес': 1},
#  'молодой': {'(': 1},
#  'роналда': {'неймар': 11,
#   'месси': 22,
#   'мбапп': 9,
#   'салах': 4,
#   'кейн': 8,
#   'акинфей': 2,
#   'макгрегор': 2,
#   'головин': 2,
#   'дзюба': 2,
#   'смолов': 1,
#   'акинфеев': 2,
#   'черчесов': 1,
#   'трамп': 1,
#   'путин': 2,
#   'модрич': 8,
#   'черчес': 1,
#   'дженнер': 1,
#   'кардашьян': 1,
#   'черышев': 1,
#   'нурмагомедов': 1},
#  'неймар': {'роналда': 11,
#   'месси': 6,
#   'кейн': 3,
#   'акинфей': 1,
#   'уильямс': 1,
#   'смолов': 1,
#   'головин': 1,
#   'черчесов': 2,
#   'игнашевич': 1,
#   'салах': 1,
#   'мбапп': 5,
#   'модрич': 6,
#   'смит': 1,
#   'фернандес': 1,
#   'лавров': 1,
#   'захаров': 1},
#  'кудрявцев': {'путин': 16,
#   'белоусов': 5,
#   '.': 2,
#   'орешкин': 4,
#   'силуановый': 6,
#   'макаров': 2,
#   'маска': 1,
#   'трамп': 1,
#   'дерипаска': 1,
#   'медведев': 2,
#   'володин': 1,
#   'рогозин': 1,
#   'кадыров': 1,
#   'мартин': 1,
#   'песков': 1,
#   'иванов': 1},
#  'смит': {'черчесов': 1,
#   'овечкин': 1,
#   'неймар': 1,
#   'макрон': 1,
#   'путин': 1,
#   '(': 1,
#   'кардашьян': 1,
#   'дженнер': 1,
#   'уэст': 1,
#   'джонсон': 1},
#  'головин': {'черчесов': 7,
#   'черышев': 9,
#   'смолов': 5,
#   'дзюба': 13,
#   'акинфей': 11,
#   'игнашевич': 12,
#   'фернандес': 8,
#   'салах': 2,
#   'месси': 2,
#   'роналда': 2,
#   'неймар': 1,
#   'путин': 1,
#   'черчес': 3,
#   'акинфеев': 3,
#   'васильев': 3,
#   'мбапп': 1},
#  '(': {'месси': 1,
#   'акинфей': 1,
#   'дерипаска': 3,
#   'трамп': 1,
#   'молодой': 1,
#   'смит': 1,
#   'кейн': 1},
#  'марков': {'воробьев': 7},
#  'ын': {'трамп': 72,
#   'кардашьян': 1,
#   'джонсон': 1,
#   'ким': 9,
#   'ына': 45,
#   'асад': 1,
#   'лавров': 13,
#   'обама': 2,
#   'путин': 17,
#   'песков': 2,
#   'сандерс': 4,
#   'болтон': 2,
#   'помпео': 11,
#   'ельцин': 1,
#   'цзиньпин': 5},
#  'кардашьян': {'джонсон': 4,
#   'ын': 1,
#   'ким': 5,
#   'трамп': 4,
#   'уэст': 21,
#   'дженнер': 17,
#   'кейн': 1,
#   'уильямс': 1,
#   'роналда': 1,
#   'смит': 1},
#  'ким': {'кардашьян': 5,
#   'джонсон': 1,
#   'ын': 9,
#   'трамп': 13,
#   'ына': 5,
#   'уэст': 1,
#   'кейн': 1,
#   'помпео': 2,
#   'овечкин': 1,
#   'дженнер': 3,
#   'лавров': 1,
#   'путин': 1},
#  'сенцов': {'порошенко': 4,
#   'путин': 11,
#   'москальков': 15,
#   'климкин': 2,
#   'песков': 5,
#   'иванов': 2,
#   'макаров': 1,
#   'герман': 1,
#   'бабченко': 1,
#   'омелян': 1,
#   '.': 2},
#  'медведев': {'путин': 54,
#   'топилина': 16,
#   'иванов': 1,
#   'силуановый': 16,
#   'песков': 10,
#   'скрипаля': 1,
#   'скрипаль': 1,
#   'джонсон': 1,
#   'юлия': 1,
#   'ельцин': 3,
#   'кирилл': 1,
#   'ii': 1,
#   'шойгу': 1,
#   'воробьев': 2,
#   'володин': 3,
#   'акинфей': 1,
#   'черчесов': 1,
#   'макаров': 3,
#   'орешкин': 2,
#   'кудрявцев': 2,
#   'рогозин': 2,
#   '.': 1,
#   'столтенберг': 2,
#   'обама': 1,
#   'трамп': 3,
#   'порошенко': 1,
#   'цзиньпин': 1,
#   'клинтон': 1},
#  'орешкин': {'дерипаска': 2,
#   'путин': 7,
#   'кудрявцев': 4,
#   'трамп': 3,
#   'кадыров': 2,
#   'песков': 1,
#   'медведев': 2,
#   'силуановый': 2,
#   'белоусов': 1},
#  'дерипаска': {'орешкин': 2,
#   'помпео': 1,
#   'путин': 2,
#   'кудрявцев': 1,
#   'трамп': 3,
#   '(': 3},
#  'луценко': {'герман': 4,
#   'бабченко': 5,
#   'климкин': 2,
#   'иванов': 1,
#   'путин': 3,
#   'вид': 3,
#   'омелян': 1,
#   'порошенко': 2,
#   'москальков': 1,
#   'гройсман': 1},
#  'юнкер': {'трамп': 14,
#   'макрон': 8,
#   'меркель': 2,
#   'порошенко': 2,
#   'сандерс': 1,
#   'путин': 1},
#  'лукашенко': {'путин': 7, 'дзюба': 1, 'асад': 1, 'кобзон': 1, 'макаров': 1},
#  'петросян': {'кадыров': 2, 'кирилл': 4, 'путин': 5, 'иванов': 1},
#  'овечкин': {'кузнецов': 4,
#   'смит': 1,
#   'трамп': 3,
#   'черчесов': 1,
#   'ким': 1,
#   'путин': 2},
#  'уэст': {'кардашьян': 21,
#   'трамп': 3,
#   'ким': 1,
#   'кейн': 1,
#   'порошенко': 1,
#   '.': 1,
#   'дженнер': 1,
#   'смит': 1},
#  'эрдоган': {'путин': 9,
#   'трамп': 14,
#   'мэй': 1,
#   'гюлен': 18,
#   'порошенко': 1,
#   'брансон': 15,
#   'силуановый': 1,
#   'песков': 1},
#  'мэй': {'трамп': 15,
#   'макрон': 2,
#   'меркель': 3,
#   'скрипаля': 3,
#   'юлия': 4,
#   'ii': 6,
#   'джонсон': 19,
#   'путин': 4,
#   'лавров': 1,
#   'захаров': 1,
#   'мартин': 1,
#   'миддлтон': 2,
#   'эрдоган': 1,
#   'обама': 1,
#   'скрипаль': 1,
#   'стерджесс': 1,
#   'роули': 1,
#   'песков': 2},
#  'климкин': {'бабченко': 1,
#   'луценко': 2,
#   'ына': 1,
#   'трамп': 3,
#   'путин': 3,
#   'порошенко': 6,
#   'сандерс': 1,
#   'макрон': 1,
#   'меркель': 2,
#   'песков': 2,
#   'сенцов': 2,
#   'омелян': 1},
#  'силуановый': {'кудрявцев': 6,
#   'макаров': 2,
#   'путин': 9,
#   'медведев': 16,
#   'топилина': 3,
#   'орешкин': 2,
#   'эрдоган': 1,
#   'скрипаля': 1,
#   'белоусов': 5},
#  'макрон': {'воробьев': 1,
#   'путин': 10,
#   'мэй': 2,
#   'меркель': 7,
#   'трамп': 11,
#   'юнкер': 8,
#   'сандерс': 1,
#   'климкин': 1,
#   'песков': 4,
#   'скрипаля': 4,
#   'джонсон': 1,
#   'порошенко': 2,
#   'смит': 1,
#   'мбапп': 1,
#   'модрич': 2,
#   'асад': 1},
#  'уильямс': {'смолов': 1,
#   'неймар': 1,
#   'кирилл': 3,
#   'черчесов': 1,
#   'путин': 2,
#   'месси': 1,
#   'макаров': 1,
#   'кардашьян': 1,
#   'мартин': 1,
#   'марклый': 1,
#   'гарри': 1},
#  'вагнер': {'расторгуев': 17,
#   'радченко': 17,
#   'захаров': 9,
#   'кадыров': 1,
#   'мартин': 1},
#  'вайнштейн': {'клинтон': 1, 'володин': 1, 'трамп': 2, 'сандерс': 1},
#  'столтенберг': {'порошенко': 5,
#   'скрипаля': 2,
#   'скрипаль': 2,
#   'герман': 1,
#   'бабченко': 1,
#   'помпео': 1,
#   'болтон': 1,
#   'песков': 2,
#   'трамп': 5,
#   'путин': 5,
#   'иванов': 1,
#   'юлия': 1,
#   'медведев': 2},
#  'кузнецов': {'овечкин': 4,
#   'воробьев': 1,
#   'путин': 2,
#   'ельцин': 1,
#   'рогозин': 1},
#  'асад': {'ын': 1,
#   'ына': 1,
#   'трамп': 6,
#   'путин': 15,
#   'болтон': 6,
#   'песков': 2,
#   'макрон': 1,
#   'скрипаля': 1,
#   'юлия': 1,
#   'меркель': 2,
#   'лукашенко': 1,
#   'лавров': 2,
#   'помпео': 1},
#  'месси': {'роналда': 22,
#   'мбапп': 4,
#   'салах': 6,
#   'кейн': 4,
#   'акинфей': 2,
#   'неймар': 6,
#   'макгрегор': 1,
#   'головин': 2,
#   'дзюба': 1,
#   'смолов': 1,
#   'черчесов': 2,
#   'игнашевич': 1,
#   'модрич': 6,
#   'кадыров': 1,
#   'кобзон': 1,
#   'обама': 1,
#   'песков': 1,
#   'акинфеев': 1,
#   '(': 1,
#   'уильямс': 1,
#   'черчес': 1},
#  'скрипаля': {'юлия': 38,
#   'путин': 15,
#   'скрипаль': 23,
#   'мэй': 3,
#   'ii': 1,
#   'джонсон': 4,
#   'герман': 1,
#   'бабченко': 1,
#   'столтенберг': 2,
#   'медведев': 1,
#   'стерджесс': 10,
#   'роули': 5,
#   'макрон': 4,
#   'песков': 4,
#   'трамп': 5,
#   'асад': 1,
#   'захаров': 3,
#   'лавров': 1,
#   'силуановый': 1},
#  'юлия': {'скрипаля': 38,
#   'путин': 9,
#   'скрипаль': 47,
#   'мэй': 4,
#   'ii': 1,
#   'джонсон': 2,
#   'медведев': 1,
#   'стерджесс': 28,
#   'роули': 27,
#   'песков': 2,
#   'столтенберг': 1,
#   'трамп': 3,
#   'захарченко': 1,
#   'асад': 1,
#   'захаров': 1,
#   'лавров': 1},
#  'черышев': {'черчесов': 6,
#   'смолов': 3,
#   'дзюба': 14,
#   'акинфей': 5,
#   'головин': 9,
#   'игнашевич': 4,
#   'фернандес': 9,
#   'салах': 5,
#   'акинфеев': 4,
#   'черчес': 3,
#   'вид': 1,
#   'модрич': 1,
#   'роналда': 1,
#   'путин': 1},
#  'смолов': {'черчесов': 6,
#   'черышев': 3,
#   'дзюба': 9,
#   'акинфей': 4,
#   'головин': 5,
#   'игнашевич': 3,
#   'фернандес': 5,
#   'месси': 1,
#   'роналда': 1,
#   'уильямс': 1,
#   'неймар': 1,
#   'кадыров': 1,
#   'черчес': 4,
#   'вид': 1,
#   'акинфеев': 2},
#  'дзюба': {'черчесов': 11,
#   'черышев': 14,
#   'смолов': 9,
#   'акинфей': 11,
#   'головин': 13,
#   'игнашевич': 12,
#   'фернандес': 9,
#   'месси': 1,
#   'роналда': 2,
#   'кадыров': 3,
#   'салах': 4,
#   'акинфеев': 9,
#   'черчес': 7,
#   'мбапп': 2,
#   'модрич': 2,
#   'вид': 1,
#   'путин': 2,
#   'лукашенко': 1},
#  'акинфей': {'черчесов': 4,
#   'черышев': 5,
#   'смолов': 4,
#   'дзюба': 11,
#   'головин': 11,
#   'игнашевич': 9,
#   'фернандес': 9,
#   'месси': 2,
#   'роналда': 2,
#   'кейн': 1,
#   'неймар': 1,
#   'акинфеев': 11,
#   'салах': 1,
#   'черчес': 4,
#   'песков': 1,
#   'медведев': 1,
#   'иванов': 1,
#   '(': 1,
#   'путин': 1},
#  'игнашевич': {'черчесов': 6,
#   'черышев': 4,
#   'смолов': 3,
#   'дзюба': 12,
#   'акинфей': 9,
#   'головин': 12,
#   'фернандес': 7,
#   'месси': 1,
#   'салах': 2,
#   'неймар': 1,
#   'черчес': 4,
#   'акинфеев': 3,
#   'кадыров': 1,
#   'вид': 1,
#   'путин': 1},
#  'фернандес': {'черчесов': 6,
#   'черышев': 9,
#   'смолов': 5,
#   'дзюба': 9,
#   'акинфей': 9,
#   'головин': 8,
#   'игнашевич': 7,
#   'салах': 1,
#   'черчес': 3,
#   'вид': 2,
#   'кадыров': 1,
#   'неймар': 1,
#   'модрич': 1,
#   'кейн': 1,
#   'акинфеев': 1},
#  'маск': {'маска': 24, 'рогозин': 1},
#  'обама': {'лавров': 1,
#   'ын': 2,
#   'ына': 1,
#   'трамп': 26,
#   'путин': 8,
#   'месси': 1,
#   'кадыров': 1,
#   'кобзон': 1,
#   'песков': 1,
#   'салах': 1,
#   'сандерс': 1,
#   'мэй': 1,
#   'ii': 3,
#   'болтон': 1,
#   'бутин': 4,
#   'медведев': 1,
#   'клинтон': 1,
#   'коэн': 1},
#  'ii': {'кирилл': 2,
#   'скрипаля': 1,
#   'юлия': 1,
#   'мэй': 6,
#   'марклый': 16,
#   'гарри': 16,
#   'миддлтон': 9,
#   'коэн': 1,
#   'медведев': 1,
#   'ельцин': 1,
#   'путин': 1,
#   'обама': 3,
#   'трамп': 10,
#   'володин': 1,
#   'кейн': 1,
#   'джонсон': 2,
#   'клинтон': 1},
#  'меркель': {'макрон': 7,
#   'мэй': 3,
#   'трамп': 22,
#   'песков': 12,
#   'путин': 25,
#   'сандерс': 1,
#   'климкин': 2,
#   'юнкер': 2,
#   'помпео': 2,
#   'ельцин': 1,
#   'джонсон': 1,
#   'захарченко': 1,
#   'асад': 2,
#   'лавров': 1,
#   'болтон': 3,
#   'порошенко': 1,
#   'кадыров': 1},
#  'мартин': {'мэй': 1,
#   'марклый': 3,
#   'гарри': 3,
#   'уильямс': 1,
#   'захаров': 1,
#   'кудрявцев': 1,
#   'путин': 1,
#   'вагнер': 1,
#   'расторгуев': 2,
#   'радченко': 2},
#  'дженнер': {'кардашьян': 17,
#   'роналда': 1,
#   'смит': 1,
#   'ким': 3,
#   'уэст': 1,
#   'джонсон': 1},
#  'помпео': {'трамп': 29,
#   'ын': 11,
#   'ына': 6,
#   'ельцин': 1,
#   'путин': 9,
#   'болтон': 7,
#   'дерипаска': 1,
#   'песков': 3,
#   'столтенберг': 1,
#   'меркель': 2,
#   'ким': 2,
#   'сандерс': 1,
#   'лавров': 2,
#   'захаров': 1,
#   'асад': 1},
#  'коэн': {'марклый': 1,
#   'ii': 1,
#   'трамп': 11,
#   'клинтон': 1,
#   'обама': 1,
#   'путин': 1},
#  'мбапп': {'месси': 4,
#   'роналда': 9,
#   'салах': 2,
#   'кейн': 4,
#   'неймар': 5,
#   'модрич': 8,
#   'акинфеев': 1,
#   'дзюба': 2,
#   'макрон': 1,
#   'черчес': 1,
#   'васильев': 1,
#   'головин': 1},
#  'кейн': {'месси': 4,
#   'роналда': 8,
#   'мбапп': 4,
#   'салах': 2,
#   'акинфей': 1,
#   'неймар': 3,
#   'кардашьян': 1,
#   'уэст': 1,
#   'ким': 1,
#   'марклый': 1,
#   'гарри': 1,
#   'акинфеев': 1,
#   'черчесов': 2,
#   'модрич': 4,
#   'фернандес': 1,
#   'черчес': 1,
#   'ii': 1,
#   '(': 1},
#  'скрипаль': {'скрипаля': 23,
#   'юлия': 47,
#   'путин': 5,
#   'герман': 1,
#   'бабченко': 1,
#   'столтенберг': 2,
#   'медведев': 1,
#   'джонсон': 1,
#   'стерджесс': 28,
#   'роули': 26,
#   'песков': 2,
#   'мэй': 1,
#   'трамп': 2,
#   'ельцин': 1,
#   'захарченко': 1},
#  'захарченко': {'порошенко': 1,
#   'путин': 5,
#   'скрипаль': 1,
#   'юлия': 1,
#   'меркель': 1,
#   'захаров': 4},
#  'топилина': {'медведев': 16, 'путин': 2, 'силуановый': 3, 'володин': 1},
#  'кадыров': {'дзюба': 3,
#   'черчесов': 2,
#   'смолов': 1,
#   'салах': 12,
#   'петросян': 2,
#   'путин': 12,
#   'месси': 1,
#   'кобзон': 1,
#   'обама': 1,
#   'песков': 7,
#   'иванов': 1,
#   'орешкин': 2,
#   'фернандес': 1,
#   'игнашевич': 1,
#   'кудрявцев': 1,
#   'вагнер': 1,
#   'расторгуев': 1,
#   'радченко': 1,
#   'джонсон': 2,
#   'собянин': 4,
#   'трамп': 1,
#   'меркель': 1},
#  'клинтон': {'вайнштейн': 1,
#   'трамп': 23,
#   'болтон': 2,
#   'путин': 9,
#   'обама': 1,
#   'ii': 1,
#   'коэн': 1,
#   'медведев': 1,
#   'ельцин': 4,
#   'песков': 1},
#  'лебедев': {'путин': 1, 'воробьев': 1},
#  'борисов': {'путин': 4, 'макаров': 1, 'воробьев': 1, 'кобзон': 1},
#  '.': {'кудрявцев': 2,
#   'белоусов': 1,
#   'путин': 2,
#   'порошенко': 1,
#   'герман': 3,
#   'бабченко': 3,
#   'володин': 1,
#   'медведев': 1,
#   'сенцов': 2,
#   'уэст': 1},
#  'собянин': {'воробьев': 12, 'путин': 1, 'кадыров': 4, 'песков': 2},
#  'володин': {'вайнштейн': 1,
#   'медведев': 3,
#   'шойгу': 1,
#   'воробьев': 1,
#   'путин': 3,
#   'кудрявцев': 1,
#   'ii': 1,
#   'топилина': 1,
#   '.': 1},
#  'сандерс': {'ын': 4,
#   'ына': 3,
#   'трамп': 23,
#   'песков': 2,
#   'климкин': 1,
#   'макрон': 1,
#   'меркель': 1,
#   'обама': 1,
#   'вайнштейн': 1,
#   'болтон': 5,
#   'путин': 7,
#   'помпео': 1,
#   'юнкер': 1},
#  'цзиньпин': {'путин': 13,
#   'трамп': 8,
#   'песков': 2,
#   'лавров': 3,
#   'ын': 5,
#   'ына': 3,
#   'медведев': 1},
#  'черчес': {'черчесов': 22,
#   'головин': 3,
#   'дзюба': 7,
#   'черышев': 3,
#   'игнашевич': 4,
#   'акинфей': 4,
#   'фернандес': 3,
#   'песков': 1,
#   'путин': 6,
#   'смолов': 4,
#   'месси': 1,
#   'роналда': 1,
#   'мбапп': 1,
#   'модрич': 1,
#   'салах': 1,
#   'кейн': 1,
#   'акинфеев': 3},
#  'шойгу': {'медведев': 1,
#   'воробьев': 2,
#   'володин': 1,
#   'путин': 11,
#   'иванов': 2,
#   'лавров': 1,
#   'песков': 8,
#   'ельцин': 1},
#  'макгрегор': {'месси': 1,
#   'роналда': 2,
#   'нурмагомедов': 27,
#   'нурмагомед': 24,
#   'путин': 1,
#   'трамп': 2},
#  'марклый': {'гарри': 58,
#   'ii': 16,
#   'миддлтон': 19,
#   'коэн': 1,
#   'трамп': 1,
#   'кейн': 1,
#   'джонсон': 1,
#   'ына': 1,
#   'мартин': 3,
#   'уильямс': 1},
#  'гарри': {'марклый': 58,
#   'ii': 16,
#   'миддлтон': 15,
#   'трамп': 1,
#   'кейн': 1,
#   'джонсон': 1,
#   'ына': 1,
#   'мартин': 3,
#   'уильямс': 1},
#  'кобзон': {'месси': 1,
#   'кадыров': 1,
#   'обама': 1,
#   'песков': 1,
#   'салах': 1,
#   'путин': 1,
#   'борисов': 1,
#   'макаров': 2,
#   'лукашенко': 1},
#  'рогозин': {'путин': 3,
#   'трамп': 1,
#   'медведев': 2,
#   'кудрявцев': 1,
#   'маска': 2,
#   'маск': 1,
#   'кирилл': 1,
#   'кузнецов': 1},
#  'кирилл': {'ii': 2,
#   'уильямс': 3,
#   'путин': 8,
#   'черчесов': 1,
#   'медведев': 1,
#   'ельцин': 1,
#   'воробьев': 1,
#   'петросян': 4,
#   'рогозин': 1},
#  'миддлтон': {'марклый': 19,
#   'ii': 9,
#   'гарри': 15,
#   'мэй': 2,
#   'джонсон': 1,
#   'ына': 1},
#  'гройсман': {'порошенко': 5,
#   'трамп': 1,
#   'путин': 2,
#   'омелян': 1,
#   'луценко': 1},
#  'белоусов': {'кудрявцев': 5,
#   '.': 1,
#   'путин': 18,
#   'песков': 4,
#   'силуановый': 5,
#   'орешкин': 1},
#  'ельцин': {'путин': 12,
#   'ын': 1,
#   'помпео': 1,
#   'ына': 1,
#   'трамп': 1,
#   'кузнецов': 1,
#   'медведев': 3,
#   'кирилл': 1,
#   'ii': 1,
#   'песков': 4,
#   'скрипаль': 1,
#   'меркель': 1,
#   'шойгу': 1,
#   'клинтон': 4},
#  'захаров': {'джонсон': 1,
#   'лавров': 5,
#   'мэй': 1,
#   'воробьев': 6,
#   'порошенко': 1,
#   'неймар': 1,
#   'вагнер': 9,
#   'расторгуев': 8,
#   'радченко': 8,
#   'мартин': 1,
#   'скрипаля': 3,
#   'юлия': 1,
#   'бутин': 3,
#   'трамп': 2,
#   'москальков': 1,
#   'помпео': 1,
#   'захарченко': 4},
#  'болтон': {'ын': 2,
#   'ына': 1,
#   'трамп': 35,
#   'клинтон': 2,
#   'помпео': 7,
#   'путин': 30,
#   'песков': 9,
#   'столтенберг': 1,
#   'лавров': 3,
#   'асад': 6,
#   'сандерс': 5,
#   'обама': 1,
#   'меркель': 3,
#   'порошенко': 2},
#  'нурмагомедов': {'макгрегор': 27, 'нурмагомед': 18, 'трамп': 2, 'роналда': 1},
#  'нурмагомед': {'макгрегор': 24, 'нурмагомедов': 18, 'трамп': 2},
#  'маска': {'маск': 24, 'кудрявцев': 1, 'рогозин': 2},
#  'макаров': {'кудрявцев': 2,
#   'силуановый': 2,
#   'путин': 3,
#   'борисов': 1,
#   'иванов': 1,
#   'сенцов': 1,
#   'медведев': 3,
#   'уильямс': 1,
#   'кобзон': 2,
#   'лукашенко': 1},
#  'москальков': {'сенцов': 15,
#   'порошенко': 2,
#   'путин': 6,
#   'луценко': 1,
#   'трамп': 1,
#   'бутин': 2,
#   'захаров': 1},
#  'модрич': {'месси': 6,
#   'роналда': 8,
#   'мбапп': 8,
#   'неймар': 6,
#   'черчесов': 2,
#   'черышев': 1,
#   'кейн': 4,
#   'фернандес': 1,
#   'акинфеев': 1,
#   'дзюба': 2,
#   'макрон': 2,
#   'салах': 2,
#   'черчес': 1,
#   'путин': 1},
#  'акинфеев': {'салах': 5,
#   'дзюба': 9,
#   'черышев': 4,
#   'месси': 1,
#   'роналда': 2,
#   'черчесов': 5,
#   'кейн': 1,
#   'акинфей': 11,
#   'головин': 3,
#   'игнашевич': 3,
#   'иванов': 1,
#   'путин': 1,
#   'мбапп': 1,
#   'модрич': 1,
#   'черчес': 3,
#   'воробьев': 1,
#   'смолов': 2,
#   'фернандес': 1},
#  'стерджесс': {'скрипаля': 10,
#   'скрипаль': 28,
#   'юлия': 28,
#   'роули': 26,
#   'мэй': 1},
#  'роули': {'скрипаля': 5,
#   'скрипаль': 26,
#   'юлия': 27,
#   'стерджесс': 26,
#   'мэй': 1},
#  'вид': {'черышев': 1,
#   'фернандес': 2,
#   'луценко': 3,
#   'порошенко': 2,
#   'путин': 1,
#   'дзюба': 1,
#   'игнашевич': 1,
#   'смолов': 1},
#  'гюлен': {'эрдоган': 18,
#   'порошенко': 1,
#   'путин': 1,
#   'брансон': 16,
#   'трамп': 14},
#  'омелян': {'порошенко': 3,
#   'луценко': 1,
#   'путин': 1,
#   'сенцов': 1,
#   'гройсман': 1,
#   'климкин': 1},
#  'бутин': {'обама': 4, 'трамп': 4, 'путин': 1, 'захаров': 3, 'москальков': 2},
#  'брансон': {'гюлен': 16, 'эрдоган': 15, 'трамп': 16, 'песков': 1},
#  'расторгуев': {'вагнер': 17,
#   'радченко': 25,
#   'захаров': 8,
#   'кадыров': 1,
#   'мартин': 2},
#  'радченко': {'вагнер': 17,
#   'расторгуев': 25,
#   'захаров': 8,
#   'кадыров': 1,
#   'мартин': 2}}

# %% [markdown]
# А теперь построим этот граф при помощи библиотеки <a href="https://networkx.github.io/documentation/stable/_downloads/networkx_reference.pdf">NetworkX</a>

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
#import pygraphviz
import networkx as nx
import math
import numpy as np
# Out:
# /home/edward/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# Построим граф связей при помощи библиотеки networkx.

# %%
# Определим функцию отрисовки графа.
def form_social_graph(persons):
    # Добавляем дуги в граф. Вершины добавятся из названий дуг.
    G = nx.Graph()
    # Перебираем все найденные персоны.
    for n in persons.keys():
        for n2 in persons[n].keys():
            # Собственно, добавляем дугу к графу. Вершины добавятся сами.
            G.add_edge(n, n2)
    return G

# %%
G1 = form_social_graph(pers2)

# %% [markdown]
# А теперь отобразим полученный граф. Вообще-то, по умолчанию для графа не задано расположение его вершин, а мы не хотим задавать их вручную. Используем для этого функцию spring_layout, которая считает, что каждая связь - это пружина, которая притягивает вершины поближе, тогда как вершины, между которыми нет связи, отталкиваются.
#
# Помимо этого зададим линии дуги так, чтобы их ширина зависела от частоты связи, а размер вершины зависел ль частоты упоминания имени.

# %%
# Определим функцию отрисовки графа.
def draw_social_graph(G, persons, freqs, colors='b', layout='spring'):
    # Строим расположение вершин графа на плоскости.
    if layout == 'kawai':
        pstn = nx.kamada_kawai_layout(G)
    elif layout == 'circle':
        pstn = nx.drawing.layout.circular_layout(G2)
    elif layout == 'random':
        pstn = nx.drawing.layout.random_layout(G2)
    else:
        pstn = nx.spring_layout(G)
    # Размер вершины зависит от частоты упоминания.
    sz = [freqs[n] for n in G.nodes]
    # Толщина линии дуги зависит от логарифма частоты совместной встречаемости участников новости.
    lw = [math.log(persons[e[0]][e[1]], 10) + 1 for e in G.edges]
    # Рисуем граф.
    nx.draw(G, pos=pstn, node_color=colors, edge_color='g', with_labels=True, node_size=sz, width=lw);

# %%
draw_social_graph(G1, pers2, names)
# Out:
# <div id='c341a4fc-7fe5-44c4-9bb8-043fedf878be'></div>

# %% [markdown]
# Получился довольно-таки интересный граф, в котором видно несколько групп персонажей новостей: Путин связан с Трампом через Песок (Песков). С Порошенко связаны Захаров, Гройсман, Бабченко и другие (в том числе - Захарченко). К той же группе принадлежит девушка Рада по фамилии Верховная. Образуют кластер Фернандес, Черышев, Черчёс(ов), Акинфеев.

# %% [markdown]
# #### Меры центральности
#
# Посмотрим как можно еще работать с графами. Подавляющее большинство функций находится собственно в библиотеке networx и вызывается из нее, в качестве параметра получая граф.
#
# Рассчитываем параметр betweenness centrality для каждой вершины графа, приписываем каждой вершине графа параметр betweenness с вычисленным значением.

# %%
bb = nx.betweenness_centrality(G1)
# Кстати, значения можно просто приписать вершинам. Но мы здесь не будем это использовать.
nx.set_node_attributes(G1, bb, 'betweenness')

gclr = [bb[i] for i in G1.nodes()]
draw_social_graph(G1, pers2, names, gclr)
#drawASocialGraph(G1, pers2, names)
# Out:
# <div id='caf4814c-a2a2-4638-aab9-2bd8d5718142'></div>

# %% [markdown]
# Давайте попробуем убрать несколько наиболее упоминаемых политиков из графа чтобы понять через кто еще является ключевой фигурой в новостях.

# %%
from copy import deepcopy

G3 = deepcopy(G1)

G3.remove_node('путин')
G3.remove_node('медведев')
G3.remove_node('трамп')
G3.remove_node('порошенко')
G3.remove_node('воробьев')
G3.remove_node('роналда')
G3.remove_node('клинтон')

# %%
bb2 = nx.betweenness_centrality(G3)
gclr = [bb2[i] for i in G3.nodes()]
draw_social_graph(G3, pers2, names, gclr)
# Out:
# <div id='b477d1f1-59ac-4919-955f-f95ed9429643'></div>

# %% [markdown]
# Как видите, граф перестал быть связным. Построим расположение вершин при помощи другого алгоритма, который берет максимальный связный подграф.

# %%
draw_social_graph(G3, pers2, names, gclr, 'kawai')
# Out:
# <div id='8fea0270-42bb-425b-8548-4f0c4afd86be'></div>

# %% [markdown]
# А теперь посчитаем меру кластерности для всех вершин графа и пересчитаем ее после удаления тех же вершин.

# %%
сс = nx.clustering(G1)
gclr = [сс[i] for i in G1.nodes()]
draw_social_graph(G1, pers2, names, gclr, 'kawai')
# Out:
# <div id='b3beb301-f7e3-4dc8-97da-1d138da07389'></div>

# %% [markdown]
# "Взвесим" вершины, умножив их меру кластерности на логарифм от количества соседей.

# %%
сс = nx.clustering(G1)
gclr = [сс[i]*math.log(len(G1[i].keys())) for i in G1.nodes()]
draw_social_graph(G1, pers2, names, gclr, 'kawai')
# Out:
# <div id='3e14081e-5bf5-4030-ae7b-9efd718d776e'></div>
